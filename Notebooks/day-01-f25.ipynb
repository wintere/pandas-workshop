# %% [markdown]
# # Day One: Introduction to DataFrames

# %% [markdown]
# First, import pandas using the conventional alias `pd` and check the version. Any version should > 2.0 should do.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# After downloading `IAAPI_raw_2023-10-05.csv` file from GitHub to our `data` folder, we should be able to read it in.

# %% [markdown]
# ### Project Organization

# %% [markdown]
# Let's use the `os` module to make sure that we're looking for the file in the right place: the folder that has our Jupyter notebook in it.

# %% [markdown]
# The first function we'll use with os is `os.getcwd()` which should return the *current working directory*. This is where Python will look for files when it tries to open them if you don't specify an alternative path.

# %%
import os
os.getcwd()
# Out:
# '/Users/emwin/ProgrammingProjects/pandas-workshop/Notebooks'

# %% [markdown]
# Your folder name might be different, depending on how you set up your project and your operating system, but this is the name and path of the folder where I'm storing my workshop materials for this class.

# %% [markdown]
# The next function we'll use is `os.listdir()`, which lists the files and folders in the current directory. Do you see the `.csv` file you just downloaded?

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'IAAPI_raw_2023-10-05.csv', 'day-01-f25.ipynb']

# %% [markdown]
# Our first attempt to read in this file will fail.

# %%
moma = pd.read_csv("data/IAAPI_raw_2023-10-05.csv")
moma
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 moma = pd.read_csv("data/IAAPI_raw_2023-10-05.csv")
#       2 moma
#
# File /opt/anaconda3/envs/pandas-ws/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/pandas-ws/lib/python3.13/site-packages/pandas/io/parsers/readers.py:626, in _read(filepath_or_buffer, kwds)
#     623     return parser
#     625 with parser:
# --> 626     return parser.read(nrows)
#
# File /opt/anaconda3/envs/pandas-ws/lib/python3.13/site-packages/pandas/io/parsers/readers.py:1923, in TextFileReader.read(self, nrows)
#    1916 nrows = validate_integer("nrows", nrows)
#    1917 try:
#    1918     # error: "ParserBase" has no attribute "read"
#    1919     (
#    1920         index,
#    1921         columns,
#    1922         col_dict,
# -> 1923     ) = self._engine.read(  # type: ignore[attr-defined]
#    1924         nrows
#    1925     )
#    1926 except Exception:
#    1927     self.close()
#
# File /opt/anaconda3/envs/pandas-ws/lib/python3.13/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File pandas/_libs/parsers.pyx:838, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File pandas/_libs/parsers.pyx:905, in pandas._libs.parsers.TextReader._read_rows()
#
# File pandas/_libs/parsers.pyx:874, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File pandas/_libs/parsers.pyx:891, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File pandas/_libs/parsers.pyx:2061, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 2 fields in line 3, saw 3

# %% [markdown]
# Let's look more closely at this file. This file might have the `.csv` suffix, but it's not actually comma-separated. It has the `|` separator.

# %% [raw]
# Match point|ULAN ID|Wikidata ID|VIAF ID|LC ID|Name|Label|Birth date|Death date|Ancestry/Heritage|Indexes|Description|Watsonline|Watsonline URL|Met Collection|Met Collection URL|Wikipedia|Wikipedia URL|Art Asia America|AAA URL
# AAPI-0001|500487777|Q466654|79468708|n86857749|Abad, Pacita|Pacita Abad|1946|2004|Filipino/a/x||painter|Watsonline|https://library.metmuseum.org/search~S1/?searchtype=X&searcharg=%22Abad%2C+Pacita%22%20or%20%22Pacita%20Abad%22&searchscope=1|||Wikipedia|https://en.wikipedia.org/wiki/Pacita_Abad||
# AAPI-0970||Q47157454|102816611|no2007063757|Abbas, Hamra|Hamra Abbas|1976||Pakistani||sculptor;painter;installation artist|Watsonline|"https://library.metmuseum.org/search~S1/?searchtype=X&searcharg=""Abbas, Hamra""%20or%20""Hamra Abbas""&searchscope=1&SORT=A"||||||

# %% [markdown]
# Looking at the documentation for [**read_csv()**](https://pandas.pydata.org/docs/dev/reference/api/pandas.read_csv.html), we can pass in a `sep=` argument that tells Pandas what character (aka letter/number/symbol) is used to separate the columns in each line of this file.

# %%
moma = pd.read_csv("data/IAAPI_raw_2023-10-05.csv", sep="|")
moma
# Out:
#     Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 0     AAPI-0001  500487777.0     Q466654   79468708.0     n86857749
# 1     AAPI-0970          NaN   Q47157454  102816611.0  no2007063757
# 2     AAPI-0002  500116914.0    Q7426381   96547973.0    no99018101
# 3     AAPI-1031          NaN   Q23881684  307448466.0  no2013110010
# 4     AAPI-0003          NaN   Q19867429          NaN           NaN
# ..          ...          ...         ...          ...           ...
# 925   AAPI-0890  500524609.0   Q21607972  307424125.0   n2014002953
# 926   AAPI-0735          NaN    Q8070726          NaN           NaN
# 927   AAPI-0736          NaN  Q120867919          NaN           NaN
# 928   AAPI-0889          NaN  Q120868879          NaN           NaN
# 929   AAPI-1332  500620313.0   Q28024724  251134747.0    nr93049693
#
#                      Name                Label  Birth date  Death date  \
# 0            Abad, Pacita          Pacita Abad      1946.0      2004.0
# 1            Abbas, Hamra          Hamra Abbas      1976.0         NaN
# 2             Abe, Satoru           Satoru Abe      1926.0         NaN
# 3    Abichandani, Jaishri  Jaishri Abichandani      1969.0         NaN
# 4      Acebo Davis, Terry    Terry Acebo Davis      1953.0         NaN
# ..                    ...                  ...         ...         ...
# 925       Zheng, Chongbin       Chongbin Zheng      1961.0         NaN
# 926        Zheng, Lianjie        Lianjie Zheng      1962.0         NaN
# 927      Zheng, Shengtian      Shengtian Zheng      1938.0         NaN
# 928        Zhong, Yueying        Yueying Zhong      1960.0         NaN
# 929        Tamotzu, Chuzo        Chuzo Tamotzu      1888.0      1975.0
#
#                  Ancestry/Heritage Indexes  \
# 0                     Filipino/a/x     NaN
# 1                        Pakistani     NaN
# 2    Japanese;Hawaiian (Kamaʻāina)     NaN
# 3                           Indian     NaN
# 4                     Filipino/a/x     NaN
# ..                             ...     ...
# 925                        Chinese     NaN
# 926                        Chinese     NaN
# 927                        Chinese     NaN
# 928                        Chinese     NaN
# 929                       Japanese     NaN
#
#                                            Description  Watsonline  \
# 0                                              painter  Watsonline
# 1                 sculptor;painter;installation artist  Watsonline
# 2                                     painter;sculptor  Watsonline
# 3                             interdisciplinary artist  Watsonline
# 4    installation artist;mixed-media artist;printmaker  Watsonline
# ..                                                 ...         ...
# 925  installation artist;painter;time-based media a...  Watsonline
# 926  installation artist;painter;performance artist...  Watsonline
# 927                    painter;ink artist/calligrapher  Watsonline
# 928                    painter;ink artist/calligrapher  Watsonline
# 929                                            painter  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 0    https://library.metmuseum.org/search~S1/?searc...             NaN
# 1    https://library.metmuseum.org/search~S1/?searc...             NaN
# 2    https://library.metmuseum.org/search~S1/?searc...             NaN
# 3    https://library.metmuseum.org/search/?searchty...             NaN
# 4    https://library.metmuseum.org/search~S1/?searc...             NaN
# ..                                                 ...             ...
# 925  https://library.metmuseum.org/search/?searchty...  Met Collection
# 926  https://library.metmuseum.org/search~S1/?searc...             NaN
# 927  https://library.metmuseum.org/search~S1/?searc...             NaN
# 928  https://library.metmuseum.org/search~S1/?searc...             NaN
# 929  https://library.metmuseum.org/search/?searchty...  Met Collection
#
#                                     Met Collection URL  Wikipedia  \
# 0                                                  NaN  Wikipedia
# 1                                                  NaN        NaN
# 2                                                  NaN  Wikipedia
# 3                                                  NaN        NaN
# 4                                                  NaN  Wikipedia
# ..                                                 ...        ...
# 925  https://www.metmuseum.org/art/collection/searc...        NaN
# 926                                                NaN  Wikipedia
# 927                                                NaN        NaN
# 928                                                NaN        NaN
# 929  https://www.metmuseum.org/art/collection/searc...  Wikipedia
#
#                                         Wikipedia URL Art Asia America  \
# 0           https://en.wikipedia.org/wiki/Pacita_Abad              NaN
# 1                                                 NaN              NaN
# 2            https://en.wikipedia.org/wiki/Satoru_Abe              NaN
# 3                                                 NaN              NaN
# 4    https://en.wikipedia.org/wiki/Terry_Acebo_Davis               NaN
# ..                                                ...              ...
# 925                                               NaN              NaN
# 926       https://en.wikipedia.org/wiki/Zheng_Lianjie    artasiamerica
# 927                                               NaN              NaN
# 928                                               NaN              NaN
# 929       https://en.wikipedia.org/wiki/Chuzo_Tamotzu              NaN
#
#                                        AAA URL
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 925                                        NaN
# 926  http://artasiamerica.org/artist/detail/57
# 927                                        NaN
# 928                                        NaN
# 929                                        NaN
#
# [930 rows x 20 columns]

# %% [markdown]
# Let's make a quick adjustment so that Pandas displays all the columns in this DataFrame.

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Our next Pandas function is **DataFrame.head(n)** which displays the first *n* rows a given DataFrame.
# Now we can inspect the contents of our DataFrame.

# %%
moma.head(5) # Gives the first five rows of a DataFrame
# Out:
#   Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 0   AAPI-0001  500487777.0     Q466654   79468708.0     n86857749
# 1   AAPI-0970          NaN   Q47157454  102816611.0  no2007063757
# 2   AAPI-0002  500116914.0    Q7426381   96547973.0    no99018101
# 3   AAPI-1031          NaN   Q23881684  307448466.0  no2013110010
# 4   AAPI-0003          NaN   Q19867429          NaN           NaN
#
#                    Name                Label  Birth date  Death date  \
# 0          Abad, Pacita          Pacita Abad      1946.0      2004.0
# 1          Abbas, Hamra          Hamra Abbas      1976.0         NaN
# 2           Abe, Satoru           Satoru Abe      1926.0         NaN
# 3  Abichandani, Jaishri  Jaishri Abichandani      1969.0         NaN
# 4    Acebo Davis, Terry    Terry Acebo Davis      1953.0         NaN
#
#                Ancestry/Heritage Indexes  \
# 0                   Filipino/a/x     NaN
# 1                      Pakistani     NaN
# 2  Japanese;Hawaiian (Kamaʻāina)     NaN
# 3                         Indian     NaN
# 4                   Filipino/a/x     NaN
#
#                                          Description  Watsonline  \
# 0                                            painter  Watsonline
# 1               sculptor;painter;installation artist  Watsonline
# 2                                   painter;sculptor  Watsonline
# 3                           interdisciplinary artist  Watsonline
# 4  installation artist;mixed-media artist;printmaker  Watsonline
#
#                                       Watsonline URL Met Collection  \
# 0  https://library.metmuseum.org/search~S1/?searc...            NaN
# 1  https://library.metmuseum.org/search~S1/?searc...            NaN
# 2  https://library.metmuseum.org/search~S1/?searc...            NaN
# 3  https://library.metmuseum.org/search/?searchty...            NaN
# 4  https://library.metmuseum.org/search~S1/?searc...            NaN
#
#   Met Collection URL  Wikipedia  \
# 0                NaN  Wikipedia
# 1                NaN        NaN
# 2                NaN  Wikipedia
# 3                NaN        NaN
# 4                NaN  Wikipedia
#
#                                       Wikipedia URL Art Asia America AAA URL
# 0         https://en.wikipedia.org/wiki/Pacita_Abad              NaN     NaN
# 1                                               NaN              NaN     NaN
# 2          https://en.wikipedia.org/wiki/Satoru_Abe              NaN     NaN
# 3                                               NaN              NaN     NaN
# 4  https://en.wikipedia.org/wiki/Terry_Acebo_Davis               NaN     NaN

# %% [markdown]
# `moma` is a DataFrame object.

# %%
type(moma) # Print data type
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# If we look at the **.shape** attribute (a tuple in `(row, column)` form) we can see it has 930 rows and 20 columns.

# %%
print(moma.shape)
# Out:
# (930, 20)

# %% [markdown]
# We can look at the row names in the **.index** attribute and the column names in the **.columns** attribute--we'll learn how to change these later!
# If we do not specify an index column using the *index_col=* parameter, the row names will default to a **RangeIndex** starting at 0 and stopping at `num_rows - 1`.

# %%
moma.index
# Out:
# RangeIndex(start=0, stop=930, step=1)

# %%
moma.columns
# Out:
# Index(['Match point', 'ULAN ID', 'Wikidata ID', 'VIAF ID', 'LC ID', 'Name',
#        'Label', 'Birth date', 'Death date', 'Ancestry/Heritage', 'Indexes',
#        'Description', 'Watsonline', 'Watsonline URL', 'Met Collection',
#        'Met Collection URL', 'Wikipedia', 'Wikipedia URL', 'Art Asia America',
#        'AAA URL'],
#       dtype='object')

# %% [markdown]
# Every **column** in a **DataFrame** is a `pd.Series`, and every **row** in a **DataFrame** is a **Series**. However, columns have an assigned **Dtype** where rows do not. This makes sense because rows typically represent *observations* while columns represent *variables*.
#
# You can see the Dtypes for each column in your DataFrame using **.dtypes**. (**object** is the default Dtype for categorical variables)

# %%
moma.dtypes
# Out:
# Match point            object
# ULAN ID               float64
# Wikidata ID            object
# VIAF ID               float64
# LC ID                  object
# Name                   object
# Label                  object
# Birth date            float64
# Death date            float64
# Ancestry/Heritage      object
# Indexes                object
# Description            object
# Watsonline             object
# Watsonline URL         object
# Met Collection         object
# Met Collection URL     object
# Wikipedia              object
# Wikipedia URL          object
# Art Asia America       object
# AAA URL                object
# dtype: object

# %% [markdown]
# We can select a single column in a DataFrame by using `frame["column_name"]` notation.

# %%
moma["Name"]
# Out:
# 0              Abad, Pacita
# 1              Abbas, Hamra
# 2               Abe, Satoru
# 3      Abichandani, Jaishri
# 4        Acebo Davis, Terry
#                ...
# 925         Zheng, Chongbin
# 926          Zheng, Lianjie
# 927        Zheng, Shengtian
# 928          Zhong, Yueying
# 929          Tamotzu, Chuzo
# Name: Name, Length: 930, dtype: object

# %% [markdown]
# A column is a **pd.Series** of the same length as the number of rows in the parent **DataFrame**.

# %%
type(moma["Name"])
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Describing Distributions in DataFrames and Series
# We can get descriptive statistics for **numeric** Series or for several numeric columns in a DataFrame at once using [**DataFrame.describe()**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html).
# * count
# * mean
# * std
# * min
# * 25% quartile
# * 50% quartile (median)
# * 75% quartile
# * max

# %%
moma.describe() # On all numeric columns in a DataFrame
# Out:
#             ULAN ID       VIAF ID   Birth date   Death date
# count  3.080000e+02  4.180000e+02   820.000000   248.000000
# mean   5.002387e+08  3.184308e+20  1946.328049  1989.181452
# std    1.725383e+05  1.326401e+21    28.555683    24.795098
# min    5.000013e+08  6.613000e+03  1840.000000  1893.000000
# 25%    5.001071e+08  4.488397e+07  1928.000000  1977.500000
# 50%    5.001526e+08  9.634845e+07  1952.000000  1994.000000
# 75%    5.003364e+08  2.685018e+08  1969.000000  2008.000000
# max    5.007786e+08  9.816160e+21  1994.000000  2022.000000

# %% [markdown]
# We can compute any of the aggregate measurements from those descriptive statistics on Series or DataFrames by calling **Series.count()**, **Series.min()**, etc.

# %%
moma["Death date"].max()
# Out:
# 2022.0

# %% [markdown]
# What do you think happens if I call the **.min()** method on an alphabetical column like `Name`?

# %%
moma["Name"].min()
# Out:
# 'Abad, Pacita'

# %% [markdown]
# Aggregatation functions like **.min()** and **.count()** ignore NaN or missing values. For example, only 248 of the artists have known death dates.

# %%
moma["Death date"].count()
# Out:
# 248

# %% [markdown]
# To see a longer list of Series aggregation/computation functions, [see the official documentation](https://pandas.pydata.org/docs/reference/series.html#computations-descriptive-stats).

# %% [markdown]
# ### Categorical Variable Distributions
# But what about those columns of dtype `object` in our DataFrame? Pandas has ways for us to assess those categorical variables at a glance, even though you can't the average or standard deviation of say, a name.

# %% [markdown]
# For an individual column or Series, we can use [**Series.value_counts()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html#pandas.Series.value_counts) to compute the value frequency of categorical variables in descending order of frequency.
#
# For example, let's select the "Ancestry/Heritage" column and get its **.value_counts()**.

# %%
moma["Ancestry/Heritage"].value_counts()
# Out:
# Ancestry/Heritage
# Japanese                                                 256
# Chinese                                                  176
# Korean                                                   139
# Filipino/a/x                                              68
# Japanese;Hawaiian (Kamaʻāina)                             38
# Indian                                                    34
# Vietnamese                                                27
# Taiwanese                                                 27
# Hongkonger                                                18
# Pakistani                                                 14
# Native Hawaiian (Kānaka ʻŌiwi, Kānaka Maoli)               9
# Cambodian                                                  8
# Chinese;Hongkonger                                         8
# Chinese;Hawaiian (Kamaʻāina)                               7
# Hongkonger;Chinese                                         6
# Filipino/a/x;Hawaiian (Kamaʻāina)                          5
# Thai                                                       5
# Bangladeshi                                                4
# Chinese;Malaysian                                          3
# Singaporean                                                3
# American Samoan                                            3
# Hmong                                                      2
# Korean;Hawaiian (Kamaʻāina)                                2
# Chinese;Taiwanese                                          2
# Okinawan                                                   2
# Chinese;Japanese;Hawaiian (Kamaʻāina)                      2
# Japanese;Okinawan                                          2
# Japanese;Chinese                                           2
# Hawaiian (Kamaʻāina)                                       2
# Burmese                                                    2
# Filipino/a/x;Chinese                                       2
# Filipino/a/x;Guamanian                                     1
# Malaysian;Chinese                                          1
# Filipino/a/x;Indian                                        1
# Malaysian                                                  1
# Chinese;Thai                                               1
# Japanese;Indonesian                                        1
# Chinese;Indonesian                                         1
# Singaporean;Chinese                                        1
# Indonesian                                                 1
# Native Hawaiian (Kānaka ʻŌiwi, Kānaka Maoli);Okinawan      1
# Japanese;Native Hawaiian (Kānaka ʻŌiwi, Kānaka Maoli)      1
# Taiwanese;Chinese                                          1
# Chinese;Japanese                                           1
# Bangladeshi;Indian                                         1
# Hongkonger;Chinese;Taiwanese                               1
# Native Hawaiian (Kānaka ʻŌiwi, Kānaka Maoli);Chinese       1
# Korean;Chinese;Hawaiian (Kamaʻāina)                        1
# Samoan;Japanese                                            1
# Marshallese;Hawaiian (Kamaʻāina)                           1
# New Zealander                                              1
# Indian;New Zealander                                       1
# Korean;Japanese;Hawaiian (Kamaʻāina)                       1
# Hongkonger;Hawaiian (Kamaʻāina)                            1
# Sri Lankan                                                 1
# Okinawan;Hawaiian (Kamaʻāina)                              1
# Name: count, dtype: int64

# %% [markdown]
# Looking at this distribution, we can see that artists with ancestry from multiple Asian nations will have `;` in the `Ancestry/Heritage` column. You can also see that artists of Japanese, Chinese, and Korean descent make up the largest share.

# %% [markdown]
# To assess several categorical variables in a DataFrame, we can pass in a special flag to **DataFrame.describe()** called `include=`. Because our categorical variables are of type `object`, we'll pass in that as an argument.

# %%
moma.describe(include="object")
# Out:
#        Match point Wikidata ID      LC ID          Name        Label  \
# count          930         930        341           930          918
# unique         930         929        341           930          918
# top      AAPI-0001   Q28663102  n86857749  Abad, Pacita  Pacita Abad
# freq             1           2          1             1            1
#
#        Ancestry/Heritage                                            Indexes  \
# count                903                                                 31
# unique                56                                                  9
# top             Japanese  Index of Indigenous and Native American Artists\n
# freq                 256                                                 13
#
#        Description  Watsonline  \
# count          896         930
# unique         296           1
# top        painter  Watsonline
# freq           155         930
#
#                                            Watsonline URL  Met Collection  \
# count                                                 930              83
# unique                                                929               1
# top     https://library.metmuseum.org/search~S1/?searc...  Met Collection
# freq                                                    2              83
#
#                                        Met Collection URL  Wikipedia  \
# count                                                  83        420
# unique                                                 83          1
# top     https://www.metmuseum.org/art/collection/searc...  Wikipedia
# freq                                                    1        420
#
#                                       Wikipedia URL Art Asia America  \
# count                                           419              135
# unique                                          417                1
# top     https://en.wikipedia.org/wiki/Eiko_%26_Koma    artasiamerica
# freq                                              2              135
#
#                                           AAA URL
# count                                         135
# unique                                        135
# top     http://artasiamerica.org/artist/detail/73
# freq                                            1

# %% [markdown]
# As you can see, only **count**, **unique**, **top**, and **freq** (of the top value) are computed for string variables.

# %% [markdown]
# You can also use `include="all"` to see the numeric and categorical distributions simultaneously, but this can be a bit awkward to read.

# %%
moma.describe(include="all")
# Out:
#        Match point       ULAN ID Wikidata ID       VIAF ID      LC ID  \
# count          930  3.080000e+02         930  4.180000e+02        341
# unique         930           NaN         929           NaN        341
# top      AAPI-0001           NaN   Q28663102           NaN  n86857749
# freq             1           NaN           2           NaN          1
# mean           NaN  5.002387e+08         NaN  3.184308e+20        NaN
# std            NaN  1.725383e+05         NaN  1.326401e+21        NaN
# min            NaN  5.000013e+08         NaN  6.613000e+03        NaN
# 25%            NaN  5.001071e+08         NaN  4.488397e+07        NaN
# 50%            NaN  5.001526e+08         NaN  9.634845e+07        NaN
# 75%            NaN  5.003364e+08         NaN  2.685018e+08        NaN
# max            NaN  5.007786e+08         NaN  9.816160e+21        NaN
#
#                 Name        Label   Birth date   Death date Ancestry/Heritage  \
# count            930          918   820.000000   248.000000               903
# unique           930          918          NaN          NaN                56
# top     Abad, Pacita  Pacita Abad          NaN          NaN          Japanese
# freq               1            1          NaN          NaN               256
# mean             NaN          NaN  1946.328049  1989.181452               NaN
# std              NaN          NaN    28.555683    24.795098               NaN
# min              NaN          NaN  1840.000000  1893.000000               NaN
# 25%              NaN          NaN  1928.000000  1977.500000               NaN
# 50%              NaN          NaN  1952.000000  1994.000000               NaN
# 75%              NaN          NaN  1969.000000  2008.000000               NaN
# max              NaN          NaN  1994.000000  2022.000000               NaN
#
#                                                   Indexes Description  \
# count                                                  31         896
# unique                                                  9         296
# top     Index of Indigenous and Native American Artists\n     painter
# freq                                                   13         155
# mean                                                  NaN         NaN
# std                                                   NaN         NaN
# min                                                   NaN         NaN
# 25%                                                   NaN         NaN
# 50%                                                   NaN         NaN
# 75%                                                   NaN         NaN
# max                                                   NaN         NaN
#
#         Watsonline                                     Watsonline URL  \
# count          930                                                930
# unique           1                                                929
# top     Watsonline  https://library.metmuseum.org/search~S1/?searc...
# freq           930                                                  2
# mean           NaN                                                NaN
# std            NaN                                                NaN
# min            NaN                                                NaN
# 25%            NaN                                                NaN
# 50%            NaN                                                NaN
# 75%            NaN                                                NaN
# max            NaN                                                NaN
#
#         Met Collection                                 Met Collection URL  \
# count               83                                                 83
# unique               1                                                 83
# top     Met Collection  https://www.metmuseum.org/art/collection/searc...
# freq                83                                                  1
# mean               NaN                                                NaN
# std                NaN                                                NaN
# min                NaN                                                NaN
# 25%                NaN                                                NaN
# 50%                NaN                                                NaN
# 75%                NaN                                                NaN
# max                NaN                                                NaN
#
#         Wikipedia                                Wikipedia URL  \
# count         420                                          419
# unique          1                                          417
# top     Wikipedia  https://en.wikipedia.org/wiki/Eiko_%26_Koma
# freq          420                                            2
# mean          NaN                                          NaN
# std           NaN                                          NaN
# min           NaN                                          NaN
# 25%           NaN                                          NaN
# 50%           NaN                                          NaN
# 75%           NaN                                          NaN
# max           NaN                                          NaN
#
#        Art Asia America                                    AAA URL
# count               135                                        135
# unique                1                                        135
# top       artasiamerica  http://artasiamerica.org/artist/detail/73
# freq                135                                          1
# mean                NaN                                        NaN
# std                 NaN                                        NaN
# min                 NaN                                        NaN
# 25%                 NaN                                        NaN
# 50%                 NaN                                        NaN
# 75%                 NaN                                        NaN
# max                 NaN                                        NaN

# %% [markdown]
# Q: Let's say you're interested in studying notable artists who haven't been added to Wikipedia. How would you determine how many of the artists in this dataset do *not* have Wikipedia pages?
#
# **HINT:** Remember `.shape`?

# %% [markdown]
# A: Use the **.count()** function on the `Wikipedia` column and the first item in the `.shape` tuple to get the number of rows, then subtract.

# %%
have_wiki = moma["Wikipedia URL"].count() # Artists who do have a Wikpedia 
row_count = moma.shape[0] # Number of rows in the DataFrame
print("There are", row_count - have_wiki, "artists without Wikipedia pages featured at the MoMA in this dataset.")
# Out:
# There are 511 artists without Wikipedia pages featured at the MoMA in this dataset.

# %% [markdown]
# ## Indexing
#
# We can access values in a DataFrame using [one of two selection methods](https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html):
# * .loc[*row*, *column*] to get values by named indices and columns (inclusive on both ends)
# * .iloc[*row*, *column*] to get values by numbered indices (exclusive on the right)

# %% [markdown]
# ### Selecting from a DataFrame with the default (numeric) index
# *Q: How would you select the third column in the second row using loc? How would you select it with iloc?*
# Use this peek of the first three rows as a guide.

# %%
moma.head(3)
# Out:
#   Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 0   AAPI-0001  500487777.0     Q466654   79468708.0     n86857749
# 1   AAPI-0970          NaN   Q47157454  102816611.0  no2007063757
# 2   AAPI-0002  500116914.0    Q7426381   96547973.0    no99018101
#
#            Name        Label  Birth date  Death date  \
# 0  Abad, Pacita  Pacita Abad      1946.0      2004.0
# 1  Abbas, Hamra  Hamra Abbas      1976.0         NaN
# 2   Abe, Satoru   Satoru Abe      1926.0         NaN
#
#                Ancestry/Heritage Indexes  \
# 0                   Filipino/a/x     NaN
# 1                      Pakistani     NaN
# 2  Japanese;Hawaiian (Kamaʻāina)     NaN
#
#                             Description  Watsonline  \
# 0                               painter  Watsonline
# 1  sculptor;painter;installation artist  Watsonline
# 2                      painter;sculptor  Watsonline
#
#                                       Watsonline URL Met Collection  \
# 0  https://library.metmuseum.org/search~S1/?searc...            NaN
# 1  https://library.metmuseum.org/search~S1/?searc...            NaN
# 2  https://library.metmuseum.org/search~S1/?searc...            NaN
#
#   Met Collection URL  Wikipedia                              Wikipedia URL  \
# 0                NaN  Wikipedia  https://en.wikipedia.org/wiki/Pacita_Abad
# 1                NaN        NaN                                        NaN
# 2                NaN  Wikipedia   https://en.wikipedia.org/wiki/Satoru_Abe
#
#   Art Asia America AAA URL
# 0              NaN     NaN
# 1              NaN     NaN
# 2              NaN     NaN

# %%
print(moma.loc[1, "Wikidata ID"]) # Our index in this case is a number
print(moma.iloc[1, 2]) # The second row, the second column
# Out:
# Q47157454
# Q47157454

# %% [markdown]
# We can also use .loc and .iloc to select ranges of cells in the form of rows and columns.

# %%
moma.iloc[0:2, :] # Because iloc is not inclusive at the right end, first two rows
# Out:
#   Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 0   AAPI-0001  500487777.0     Q466654   79468708.0     n86857749
# 1   AAPI-0970          NaN   Q47157454  102816611.0  no2007063757
#
#            Name        Label  Birth date  Death date Ancestry/Heritage  \
# 0  Abad, Pacita  Pacita Abad      1946.0      2004.0      Filipino/a/x
# 1  Abbas, Hamra  Hamra Abbas      1976.0         NaN         Pakistani
#
#   Indexes                           Description  Watsonline  \
# 0     NaN                               painter  Watsonline
# 1     NaN  sculptor;painter;installation artist  Watsonline
#
#                                       Watsonline URL Met Collection  \
# 0  https://library.metmuseum.org/search~S1/?searc...            NaN
# 1  https://library.metmuseum.org/search~S1/?searc...            NaN
#
#   Met Collection URL  Wikipedia                              Wikipedia URL  \
# 0                NaN  Wikipedia  https://en.wikipedia.org/wiki/Pacita_Abad
# 1                NaN        NaN                                        NaN
#
#   Art Asia America AAA URL
# 0              NaN     NaN
# 1              NaN     NaN

# %%
moma.loc[:, "Name":"Death date"] # loc is inclusive
# Out:
#                      Name                Label  Birth date  Death date
# 0            Abad, Pacita          Pacita Abad      1946.0      2004.0
# 1            Abbas, Hamra          Hamra Abbas      1976.0         NaN
# 2             Abe, Satoru           Satoru Abe      1926.0         NaN
# 3    Abichandani, Jaishri  Jaishri Abichandani      1969.0         NaN
# 4      Acebo Davis, Terry    Terry Acebo Davis      1953.0         NaN
# ..                    ...                  ...         ...         ...
# 925       Zheng, Chongbin       Chongbin Zheng      1961.0         NaN
# 926        Zheng, Lianjie        Lianjie Zheng      1962.0         NaN
# 927      Zheng, Shengtian      Shengtian Zheng      1938.0         NaN
# 928        Zhong, Yueying        Yueying Zhong      1960.0         NaN
# 929        Tamotzu, Chuzo        Chuzo Tamotzu      1888.0      1975.0
#
# [930 rows x 4 columns]

# %%
moma.loc[:, "Name"] # Returns all the rows with the Name column
# Out:
# 0              Abad, Pacita
# 1              Abbas, Hamra
# 2               Abe, Satoru
# 3      Abichandani, Jaishri
# 4        Acebo Davis, Terry
#                ...
# 925         Zheng, Chongbin
# 926          Zheng, Lianjie
# 927        Zheng, Shengtian
# 928          Zhong, Yueying
# 929          Tamotzu, Chuzo
# Name: Name, Length: 930, dtype: object

# %% [markdown]
# Many Pandas functions use **lists** or **dictionaries** as arguments.
#
# ### Lists
# [**Lists**](https://docs.python.org/3/tutorial/datastructures.html#more-on-lists) are one-dimensional, ordered sequences. Lists can include items of heterogeneous data types. While lists have more functionality than described here, we will use them in this workshop as constants declared in the form `list_name = [item_0, item1...]`.

# %%
my_list = ["a", "b", 3, 5]
print(my_list[0]) # Gets the first item
print(my_list[:2]) # Gets the first two items
my_list.append(["dog", "cat"])
print(my_list)
# Out:
# a
# ['a', 'b']
# ['a', 'b', 3, 5, ['dog', 'cat']]

# %% [markdown]
# We can use lists to select several columns at once and in any order. You can pass it lists of column names to .loc[]. Remember `:` means select all columns or all rows.

# %%
moma.loc[:, ["Name", "Label", "Birth date"]]
# Out:
#                      Name                Label  Birth date
# 0            Abad, Pacita          Pacita Abad      1946.0
# 1            Abbas, Hamra          Hamra Abbas      1976.0
# 2             Abe, Satoru           Satoru Abe      1926.0
# 3    Abichandani, Jaishri  Jaishri Abichandani      1969.0
# 4      Acebo Davis, Terry    Terry Acebo Davis      1953.0
# ..                    ...                  ...         ...
# 925       Zheng, Chongbin       Chongbin Zheng      1961.0
# 926        Zheng, Lianjie        Lianjie Zheng      1962.0
# 927      Zheng, Shengtian      Shengtian Zheng      1938.0
# 928        Zhong, Yueying        Yueying Zhong      1960.0
# 929        Tamotzu, Chuzo        Chuzo Tamotzu      1888.0
#
# [930 rows x 3 columns]

# %% [markdown]
# You can make the list a separate variable for readability purposes.

# %%
longer_list = ["Name", "Label", "Birth date", "Death date", "Wikipedia"]
moma.loc[:, longer_list]
# Out:
#                      Name                Label  Birth date  Death date  \
# 0            Abad, Pacita          Pacita Abad      1946.0      2004.0
# 1            Abbas, Hamra          Hamra Abbas      1976.0         NaN
# 2             Abe, Satoru           Satoru Abe      1926.0         NaN
# 3    Abichandani, Jaishri  Jaishri Abichandani      1969.0         NaN
# 4      Acebo Davis, Terry    Terry Acebo Davis      1953.0         NaN
# ..                    ...                  ...         ...         ...
# 925       Zheng, Chongbin       Chongbin Zheng      1961.0         NaN
# 926        Zheng, Lianjie        Lianjie Zheng      1962.0         NaN
# 927      Zheng, Shengtian      Shengtian Zheng      1938.0         NaN
# 928        Zhong, Yueying        Yueying Zhong      1960.0         NaN
# 929        Tamotzu, Chuzo        Chuzo Tamotzu      1888.0      1975.0
#
#      Wikipedia
# 0    Wikipedia
# 1          NaN
# 2    Wikipedia
# 3          NaN
# 4    Wikipedia
# ..         ...
# 925        NaN
# 926  Wikipedia
# 927        NaN
# 928        NaN
# 929  Wikipedia
#
# [930 rows x 5 columns]
