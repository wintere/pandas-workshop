# %% [markdown]
# # Day Two: Selection, Sorting, and Nulls

# %% [markdown]
# First, import pandas using the conventional alias `pd`.

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %% [markdown]
# Read in Day One's `IAAPI_raw_2023-10-05.csv` from your `data` folder.

# %%
moma = pd.read_csv("data/IAAPI_raw_2023-10-05.csv", sep="|")
moma
# Out:
#     Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 0     AAPI-0001  500487777.0     Q466654   79468708.0     n86857749
# 1     AAPI-0970          NaN   Q47157454  102816611.0  no2007063757
# 2     AAPI-0002  500116914.0    Q7426381   96547973.0    no99018101
# 3     AAPI-1031          NaN   Q23881684  307448466.0  no2013110010
# 4     AAPI-0003          NaN   Q19867429          NaN           NaN
# ..          ...          ...         ...          ...           ...
# 925   AAPI-0890  500524609.0   Q21607972  307424125.0   n2014002953
# 926   AAPI-0735          NaN    Q8070726          NaN           NaN
# 927   AAPI-0736          NaN  Q120867919          NaN           NaN
# 928   AAPI-0889          NaN  Q120868879          NaN           NaN
# 929   AAPI-1332  500620313.0   Q28024724  251134747.0    nr93049693
#
#                      Name                Label  Birth date  Death date  \
# 0            Abad, Pacita          Pacita Abad      1946.0      2004.0
# 1            Abbas, Hamra          Hamra Abbas      1976.0         NaN
# 2             Abe, Satoru           Satoru Abe      1926.0         NaN
# 3    Abichandani, Jaishri  Jaishri Abichandani      1969.0         NaN
# 4      Acebo Davis, Terry    Terry Acebo Davis      1953.0         NaN
# ..                    ...                  ...         ...         ...
# 925       Zheng, Chongbin       Chongbin Zheng      1961.0         NaN
# 926        Zheng, Lianjie        Lianjie Zheng      1962.0         NaN
# 927      Zheng, Shengtian      Shengtian Zheng      1938.0         NaN
# 928        Zhong, Yueying        Yueying Zhong      1960.0         NaN
# 929        Tamotzu, Chuzo        Chuzo Tamotzu      1888.0      1975.0
#
#                  Ancestry/Heritage Indexes  \
# 0                     Filipino/a/x     NaN
# 1                        Pakistani     NaN
# 2    Japanese;Hawaiian (Kamaʻāina)     NaN
# 3                           Indian     NaN
# 4                     Filipino/a/x     NaN
# ..                             ...     ...
# 925                        Chinese     NaN
# 926                        Chinese     NaN
# 927                        Chinese     NaN
# 928                        Chinese     NaN
# 929                       Japanese     NaN
#
#                                            Description  Watsonline  \
# 0                                              painter  Watsonline
# 1                 sculptor;painter;installation artist  Watsonline
# 2                                     painter;sculptor  Watsonline
# 3                             interdisciplinary artist  Watsonline
# 4    installation artist;mixed-media artist;printmaker  Watsonline
# ..                                                 ...         ...
# 925  installation artist;painter;time-based media a...  Watsonline
# 926  installation artist;painter;performance artist...  Watsonline
# 927                    painter;ink artist/calligrapher  Watsonline
# 928                    painter;ink artist/calligrapher  Watsonline
# 929                                            painter  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 0    https://library.metmuseum.org/search~S1/?searc...             NaN
# 1    https://library.metmuseum.org/search~S1/?searc...             NaN
# 2    https://library.metmuseum.org/search~S1/?searc...             NaN
# 3    https://library.metmuseum.org/search/?searchty...             NaN
# 4    https://library.metmuseum.org/search~S1/?searc...             NaN
# ..                                                 ...             ...
# 925  https://library.metmuseum.org/search/?searchty...  Met Collection
# 926  https://library.metmuseum.org/search~S1/?searc...             NaN
# 927  https://library.metmuseum.org/search~S1/?searc...             NaN
# 928  https://library.metmuseum.org/search~S1/?searc...             NaN
# 929  https://library.metmuseum.org/search/?searchty...  Met Collection
#
#                                     Met Collection URL  Wikipedia  \
# 0                                                  NaN  Wikipedia
# 1                                                  NaN        NaN
# 2                                                  NaN  Wikipedia
# 3                                                  NaN        NaN
# 4                                                  NaN  Wikipedia
# ..                                                 ...        ...
# 925  https://www.metmuseum.org/art/collection/searc...        NaN
# 926                                                NaN  Wikipedia
# 927                                                NaN        NaN
# 928                                                NaN        NaN
# 929  https://www.metmuseum.org/art/collection/searc...  Wikipedia
#
#                                         Wikipedia URL Art Asia America  \
# 0           https://en.wikipedia.org/wiki/Pacita_Abad              NaN
# 1                                                 NaN              NaN
# 2            https://en.wikipedia.org/wiki/Satoru_Abe              NaN
# 3                                                 NaN              NaN
# 4    https://en.wikipedia.org/wiki/Terry_Acebo_Davis               NaN
# ..                                                ...              ...
# 925                                               NaN              NaN
# 926       https://en.wikipedia.org/wiki/Zheng_Lianjie    artasiamerica
# 927                                               NaN              NaN
# 928                                               NaN              NaN
# 929       https://en.wikipedia.org/wiki/Chuzo_Tamotzu              NaN
#
#                                        AAA URL
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 925                                        NaN
# 926  http://artasiamerica.org/artist/detail/57
# 927                                        NaN
# 928                                        NaN
# 929                                        NaN
#
# [930 rows x 20 columns]

# %% [markdown]
# ### Pandas Selection: Boolean Indexing

# %% [markdown]
# So far, we've been selecting rows and columns based on their *position* in the DataFrame.
#
# However, a more common use case is the desire to filter data by their attributes and other criteria. We will do so in Pandas with Boolean indexing.

# %% [markdown]
# [**Boolean indexing**](https://pandas.pydata.org/docs/user_guide/indexing.html#boolean-indexing) uses boolean arrays to filter the data from either a DataFrame or Series. Just like other conditional statements, operators like `==`, `>`, and `<=` can be used.

# %% [markdown]
# Booleans are returned by evaluation of conditional statements in Python.
# For example, this statement returns True, because 3 is less than 5.

# %%
3 < 5
# Out:
# True

# %% [markdown]
# We can also use comparators to get Booleans by comparing variables.

# %%
x = 10 
x == 15 # This is value. Read as "is x equal to 15"
# Out:
# False

# %% [markdown]
# In the simplest case, Boolean indexing as applied to a Series returns *another* series of Booleans.

# %%
my_s = pd.Series([1, 5, 1, -1, 10])
my_s == 1
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4    False
# dtype: bool

# %% [markdown]
# The original index is maintained, which tells us that the condition was True
# for row 0, False for row 1, and so on.

# %% [markdown]
# We can then select only the rows with `True` by passing that Boolean array back into the parent Series or DataFrame.

# %%
my_s[my_s == 1]
# Out:
# 0    1
# 2    1
# dtype: int64

# %% [markdown]
# This feature is used on columns in a DataFrame to imitiate the filtering behavior of `SELECT` statements in SQL, where *rows* are selected based on values in a specific *column*.

# %% [markdown]
# Because each column in a DataFrame represents a different observed variable, we will typically apply boolean indexing to one column at a time. For example, "Birth date" and "Name" have very different domains and ranges.

# %%
moma["Birth date"] == 1926
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4      False
#        ...
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# Name: Birth date, Length: 930, dtype: bool

# %% [markdown]
# In the simplest case, Boolean indexing as applied to a Series returns *another* series of Booleans. If use this selection to select row in the original DataFrame,
# we get a slice of the DataFrame representing the 4 artists born in 1976.

# %%
moma[moma["Birth date"] == 1926]
# Out:
#     Match point      ULAN ID Wikidata ID      VIAF ID       LC ID  \
# 2     AAPI-0002  500116914.0    Q7426381   96547973.0  no99018101
# 39    AAPI-0030  500077806.0    Q7382874   96234311.0   n86835007
# 698   AAPI-0532          NaN   Q18392945   53065616.0         NaN
# 903   AAPI-1287          NaN   Q39744310  251125388.0   n87929671
#
#                  Name            Label  Birth date  Death date  \
# 2         Abe, Satoru       Satoru Abe      1926.0         NaN
# 39        Asawa, Ruth       Ruth Asawa      1926.0      2013.0
# 698    Sekimachi, Kay    Kay Sekimachi      1926.0         NaN
# 903  Yoshimura, Fumio  Fumio Yoshimura      1926.0      2002.0
#
#                  Ancestry/Heritage Indexes  \
# 2    Japanese;Hawaiian (Kamaʻāina)     NaN
# 39                        Japanese     NaN
# 698                       Japanese     NaN
# 903                       Japanese     NaN
#
#                                   Description  Watsonline  \
# 2                            painter;sculptor  Watsonline
# 39   draftsperson;painter;printmaker;sculptor  Watsonline
# 698                      textile/fiber artist  Watsonline
# 903                                  sculptor  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 2    https://library.metmuseum.org/search~S1/?searc...             NaN
# 39   https://library.metmuseum.org/search~S1/?searc...             NaN
# 698  https://library.metmuseum.org/search~S1/?searc...  Met Collection
# 903  https://library.metmuseum.org/search~S1/?searc...  Met Collection
#
#                                     Met Collection URL  Wikipedia  \
# 2                                                  NaN  Wikipedia
# 39                                                 NaN  Wikipedia
# 698  https://www.metmuseum.org/art/collection/searc...  Wikipedia
# 903  https://www.metmuseum.org/art/collection/searc...  Wikipedia
#
#                                      Wikipedia URL Art Asia America AAA URL
# 2         https://en.wikipedia.org/wiki/Satoru_Abe              NaN     NaN
# 39        https://en.wikipedia.org/wiki/Ruth_Asawa              NaN     NaN
# 698    https://en.wikipedia.org/wiki/Kay_Sekimachi              NaN     NaN
# 903  https://en.wikipedia.org/wiki/Fumio_Yoshimura              NaN     NaN

# %% [markdown]
# One thing to note is that boolean indexing against `NaN`, `None`, or missing vlaues always returns False.

# %% [markdown]
# The 110 rows corresponding to artists with no values in the "Birth date" column are assumed *NOT* to be born on 1926.

# %% [markdown]
# Let's say we want to find out which artists in our dataset of Japanese descent were born before 1942. We need to use **boolean indexing** to select rows that fulfill specific conditions, namely, we want to artists of Japanese `Ancestry/Heritage` with a `Birth date` before 1942..

# %% [markdown]
# To start, this is how boolean indexing can be used to filter the `moma` DataFrame for artists of Japanese descent.

# %%
moma["Ancestry/Heritage"] == "Japanese" # This is a boolean index
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 925    False
# 926    False
# 927    False
# 928    False
# 929     True
# Name: Ancestry/Heritage, Length: 930, dtype: bool

# %% [markdown]
# Next, we use the boolean index to select rows from the original DataFrame.

# %%
japanese_artists = moma[moma["Ancestry/Heritage"] == "Japanese"] # This is a DataFrame 
japanese_artists
# Out:
#     Match point      ULAN ID Wikidata ID       VIAF ID       LC ID  \
# 7     AAPI-1158          NaN  Q120717678           NaN         NaN
# 8     AAPI-0005          NaN   Q29110238  7.983150e+21         NaN
# 18    AAPI-0013  500265984.0     Q771277  1.265809e+08         NaN
# 19    AAPI-1032  500372656.0   Q61997639  3.612150e+21         NaN
# 22    AAPI-0015  500442151.0  Q120411767           NaN         NaN
# ..          ...          ...         ...           ...         ...
# 893   AAPI-1109          NaN  Q120077471           NaN         NaN
# 902   AAPI-0844          NaN  Q120867916           NaN         NaN
# 903   AAPI-1287          NaN   Q39744310  2.511254e+08   n87929671
# 904   AAPI-0717          NaN    Q7982838           NaN         NaN
# 929   AAPI-1332  500620313.0   Q28024724  2.511347e+08  nr93049693
#
#                  Name                   Label  Birth date  Death date  \
# 7    Adachi, Margaret         Margaret Adachi      1952.0         NaN
# 8      Agematsu, Yuji           Yuji Agematsu      1956.0         NaN
# 18        Akamu, Nina              Nina Akamu      1955.0         NaN
# 19      Akashi, Kelly            Kelly Akashi      1983.0         NaN
# 22        Allen, John              John Allen      1955.0         NaN
# ..                ...                     ...         ...         ...
# 893   Yoneoka, Elaine          Elaine Yoneoka      1955.0         NaN
# 902   Yoshida, Sekido          Sekido Yoshida      1894.0      1965.0
# 903  Yoshimura, Fumio         Fumio Yoshimura      1926.0      2002.0
# 904  Yoshimura, Wendy  Wendy Masako Yoshimura      1943.0         NaN
# 929    Tamotzu, Chuzo           Chuzo Tamotzu      1888.0      1975.0
#
#     Ancestry/Heritage Indexes  \
# 7            Japanese     NaN
# 8            Japanese     NaN
# 18           Japanese     NaN
# 19           Japanese     NaN
# 22           Japanese     NaN
# ..                ...     ...
# 893          Japanese     NaN
# 902          Japanese     NaN
# 903          Japanese     NaN
# 904          Japanese     NaN
# 929          Japanese     NaN
#
#                                          Description  Watsonline  \
# 7    sculptor;installation artist;mixed-media artist  Watsonline
# 8                                  assemblage artist  Watsonline
# 18                                          sculptor  Watsonline
# 19                                          sculptor  Watsonline
# 22                                           painter  Watsonline
# ..                                               ...         ...
# 893           ceramicist / potter;mixed-media artist  Watsonline
# 902                               painter;printmaker  Watsonline
# 903                                         sculptor  Watsonline
# 904                                          painter  Watsonline
# 929                                          painter  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 7    https://library.metmuseum.org/search~S1/?searc...             NaN
# 8    https://library.metmuseum.org/search~S1/?searc...             NaN
# 18   https://library.metmuseum.org/search~S1/?searc...             NaN
# 19   https://library.metmuseum.org/search/?searchty...             NaN
# 22   https://library.metmuseum.org/search~S1/X?SEAR...             NaN
# ..                                                 ...             ...
# 893  https://library.metmuseum.org/search~S1/X?SEAR...             NaN
# 902  https://library.metmuseum.org/search~S1/?searc...             NaN
# 903  https://library.metmuseum.org/search~S1/?searc...  Met Collection
# 904  https://library.metmuseum.org/search~S1/X?SEAR...             NaN
# 929  https://library.metmuseum.org/search/?searchty...  Met Collection
#
#                                     Met Collection URL  Wikipedia  \
# 7                                                  NaN        NaN
# 8                                                  NaN        NaN
# 18                                                 NaN  Wikipedia
# 19                                                 NaN        NaN
# 22                                                 NaN        NaN
# ..                                                 ...        ...
# 893                                                NaN        NaN
# 902                                                NaN        NaN
# 903  https://www.metmuseum.org/art/collection/searc...  Wikipedia
# 904                                                NaN  Wikipedia
# 929  https://www.metmuseum.org/art/collection/searc...  Wikipedia
#
#                                      Wikipedia URL Art Asia America AAA URL
# 7                                              NaN              NaN     NaN
# 8                                              NaN              NaN     NaN
# 18        https://en.wikipedia.org/wiki/Nina_Akamu              NaN     NaN
# 19                                             NaN              NaN     NaN
# 22                                             NaN              NaN     NaN
# ..                                             ...              ...     ...
# 893                                            NaN              NaN     NaN
# 902                                            NaN              NaN     NaN
# 903  https://en.wikipedia.org/wiki/Fumio_Yoshimura              NaN     NaN
# 904  https://en.wikipedia.org/wiki/Wendy_Yoshimura              NaN     NaN
# 929    https://en.wikipedia.org/wiki/Chuzo_Tamotzu              NaN     NaN
#
# [256 rows x 20 columns]

# %% [markdown]
# **Q:** How can we find the artists born before 1942?

# %%
moma[moma["Birth date"] < 1942]
# Out:
#     Match point      ULAN ID Wikidata ID       VIAF ID         LC ID  \
# 2     AAPI-0002  500116914.0    Q7426381  9.654797e+07    no99018101
# 10    AAPI-1159  500464887.0    Q5292140  7.645150e+21  no2017159440
# 13    AAPI-0009          NaN   Q98505561           NaN           NaN
# 16    AAPI-0012          NaN    Q4997320  5.234150e+21  no2017156974
# 23    AAPI-0016          NaN  Q120717733           NaN           NaN
# ..          ...          ...         ...           ...           ...
# 917   AAPI-0057  500107140.0     Q163298  9.464502e+07     n83158786
# 921   AAPI-0058          NaN   Q28663102           NaN           NaN
# 923   AAPI-0070          NaN  Q120077457           NaN           NaN
# 927   AAPI-0736          NaN  Q120867919           NaN           NaN
# 929   AAPI-1332  500620313.0   Q28024724  2.511347e+08    nr93049693
#
#                          Name                                 Label  \
# 2                 Abe, Satoru                            Satoru Abe
# 10                   Ahn, Don                               Don Ahn
# 13              Ahn, Young-Il                          Young-Il Ahn
# 16              Akaji, Bumpei                          Bumpei Akaji
# 23   Alvarado, Ricardo Ocreto               Ricardo Ocreto Alvarado
# ..                        ...                                   ...
# 917             Zhang, Daqian                          Daqian Zhang
# 921              Zhang, Shuqi          Shuchi (Shuqi) Chang (Zhang)
# 923           Zhao, Chunxiang  Chung-Hsiang (Chunxiang) Chao (Zhao)
# 927          Zheng, Shengtian                       Shengtian Zheng
# 929            Tamotzu, Chuzo                         Chuzo Tamotzu
#
#      Birth date  Death date              Ancestry/Heritage Indexes  \
# 2        1926.0         NaN  Japanese;Hawaiian (Kamaʻāina)     NaN
# 10       1937.0      2013.0                         Korean     NaN
# 13       1934.0      2020.0                         Korean     NaN
# 16       1921.0      2002.0  Japanese;Hawaiian (Kamaʻāina)     NaN
# 23       1914.0      1976.0                   Filipino/a/x     NaN
# ..          ...         ...                            ...     ...
# 917      1899.0      1893.0                        Chinese     NaN
# 921      1900.0      1957.0                        Chinese     NaN
# 923      1910.0      1991.0                        Chinese     NaN
# 927      1938.0         NaN                        Chinese     NaN
# 929      1888.0      1975.0                       Japanese     NaN
#
#                                     Description  Watsonline  \
# 2                              painter;sculptor  Watsonline
# 10                                      painter  Watsonline
# 13                                      painter  Watsonline
# 16                                     sculptor  Watsonline
# 23                                 photographer  Watsonline
# ..                                          ...         ...
# 917             painter;ink artist/calligrapher  Watsonline
# 921  painter;printmaker;ink artist/calligrapher  Watsonline
# 923             painter;ink artist/calligrapher  Watsonline
# 927             painter;ink artist/calligrapher  Watsonline
# 929                                     painter  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 2    https://library.metmuseum.org/search~S1/?searc...             NaN
# 10   https://library.metmuseum.org/search~S1/?searc...             NaN
# 13   https://library.metmuseum.org/search/?searchty...             NaN
# 16   https://library.metmuseum.org/search~S1/?searc...             NaN
# 23   https://library.metmuseum.org/search/?searchty...             NaN
# ..                                                 ...             ...
# 917  https://library.metmuseum.org/search/?searchty...             NaN
# 921  https://library.metmuseum.org/search~S1/X?SEAR...  Met Collection
# 923  https://library.metmuseum.org/search~S1/X?SEAR...             NaN
# 927  https://library.metmuseum.org/search~S1/?searc...             NaN
# 929  https://library.metmuseum.org/search/?searchty...  Met Collection
#
#                                     Met Collection URL  Wikipedia  \
# 2                                                  NaN  Wikipedia
# 10                                                 NaN  Wikipedia
# 13                                                 NaN  Wikipedia
# 16                                                 NaN  Wikipedia
# 23                                                 NaN        NaN
# ..                                                 ...        ...
# 917                                                NaN  Wikipedia
# 921  https://www.metmuseum.org/art/collection/searc...  Wikipedia
# 923                                                NaN        NaN
# 927                                                NaN        NaN
# 929  https://www.metmuseum.org/art/collection/searc...  Wikipedia
#
#                                      Wikipedia URL Art Asia America  \
# 2         https://en.wikipedia.org/wiki/Satoru_Abe              NaN
# 10           https://en.wikipedia.org/wiki/Don_Ahn              NaN
# 13     https://en.wikipedia.org/wiki/Young-Il_Ahn               NaN
# 16     https://en.wikipedia.org/wiki/Bumpei_Akaji               NaN
# 23                                             NaN              NaN
# ..                                             ...              ...
# 917  https://en.wikipedia.org/wiki/Chang_Dai-chien              NaN
# 921     https://en.wikipedia.org/wiki/Zhang_Shuqi               NaN
# 923                                            NaN    artasiamerica
# 927                                            NaN              NaN
# 929    https://en.wikipedia.org/wiki/Chuzo_Tamotzu              NaN
#
#                                        AAA URL
# 2                                          NaN
# 10                                         NaN
# 13                                         NaN
# 16                                         NaN
# 23                                         NaN
# ..                                         ...
# 917                                        NaN
# 921                                        NaN
# 923  http://artasiamerica.org/artist/detail/50
# 927                                        NaN
# 929                                        NaN
#
# [306 rows x 20 columns]

# %% [markdown]
# This is getting us closer, but we're not quite there yet. We know how to find
# rows with Japanese artists, and we know how to find rows of artists born before
# 1942, but we want the *intersection* of these two groups. That is, we want
# to find the rows where both conditions are True.

# %% [markdown]
# ### Compound boolean indexing
# We want a DataFrame with both conditions combined. That is, we want to find the rows which artists in our dataset are of Japanese descent **AND** were born before 1942. this is where compound boolean indexing comes in.
#
# We can use `|` for OR and `&` for AND. The compound boolean index is in the form
# of (CONDITION) [| or &| *CONDITION).

# %%
(moma["Birth date"] < 1942) & (moma["Ancestry/Heritage"] == "Japanese") # | = or, & = and
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 925    False
# 926    False
# 927    False
# 928    False
# 929     True
# Length: 930, dtype: bool

# %% [markdown]
# Let's give this index a name `jn_pre1942` and apply it to the parent DataFrame.

# %%
jn_pre1942_index = (moma["Birth date"] < 1942) & (moma["Ancestry/Heritage"] == "Japanese") # | = or, & = and
moma[jn_pre1942_index]
# Out:
#     Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 25    AAPI-0017  500054317.0   Q19864133    1431348.0     n85027139
# 29    AAPI-0020  500465254.0   Q17421288          NaN           NaN
# 36    AAPI-0025  500123705.0     Q478264       6613.0     n79091248
# 39    AAPI-0030  500077806.0    Q7382874   96234311.0     n86835007
# 121   AAPI-0099          NaN    Q6313941   16883563.0  no2001102256
# ..          ...          ...         ...          ...           ...
# 881   AAPI-0703  500041099.0    Q7686513  108861782.0     n82056657
# 889   AAPI-0709          NaN  Q111532416          NaN           NaN
# 902   AAPI-0844          NaN  Q120867916          NaN           NaN
# 903   AAPI-1287          NaN   Q39744310  251125388.0     n87929671
# 929   AAPI-1332  500620313.0   Q28024724  251134747.0    nr93049693
#
#                  Name                     Label  Birth date  Death date  \
# 25         Amino, Leo                 Leo Amino      1911.0      1989.0
# 29       Aoki, Toshio               Toshio Aoki      1854.0      1912.0
# 36   Arakawa, Shusaku           Shusaku Arakawa      1936.0      2010.0
# 39        Asawa, Ruth                Ruth Asawa      1926.0      2013.0
# 121     Chodos, Junko  Junko Chodos (Takahashi)      1939.0         NaN
# ..                ...                       ...         ...         ...
# 881     Yashima, Taro              Taro Yashima      1908.0      1994.0
# 889   Yoda, Toshihisa            Toshihisa Yoda      1940.0         NaN
# 902   Yoshida, Sekido            Sekido Yoshida      1894.0      1965.0
# 903  Yoshimura, Fumio           Fumio Yoshimura      1926.0      2002.0
# 929    Tamotzu, Chuzo             Chuzo Tamotzu      1888.0      1975.0
#
#     Ancestry/Heritage Indexes  \
# 25           Japanese     NaN
# 29           Japanese     NaN
# 36           Japanese     NaN
# 39           Japanese     NaN
# 121          Japanese     NaN
# ..                ...     ...
# 881          Japanese     NaN
# 889          Japanese     NaN
# 902          Japanese     NaN
# 903          Japanese     NaN
# 929          Japanese     NaN
#
#                                            Description  Watsonline  \
# 25                                            sculptor  Watsonline
# 29                     painter;ink artist/calligrapher  Watsonline
# 36   architect;conceptual artist;painter;printmaker...  Watsonline
# 39            draftsperson;painter;printmaker;sculptor  Watsonline
# 121   draftsperson;mixed-media artist;painter;sculptor  Watsonline
# ..                                                 ...         ...
# 881                                illustrator;painter  Watsonline
# 889           draftsperson;installation artist;painter  Watsonline
# 902                                 painter;printmaker  Watsonline
# 903                                           sculptor  Watsonline
# 929                                            painter  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 25   https://library.metmuseum.org/search~S1/?searc...             NaN
# 29   https://library.metmuseum.org/search~S1/?searc...             NaN
# 36   https://library.metmuseum.org/search~S1/?searc...  Met Collection
# 39   https://library.metmuseum.org/search~S1/?searc...             NaN
# 121  https://library.metmuseum.org/search~S1/X?SEAR...             NaN
# ..                                                 ...             ...
# 881  https://library.metmuseum.org/search~S1/?searc...             NaN
# 889  https://library.metmuseum.org/search~S1/?searc...             NaN
# 902  https://library.metmuseum.org/search~S1/?searc...             NaN
# 903  https://library.metmuseum.org/search~S1/?searc...  Met Collection
# 929  https://library.metmuseum.org/search/?searchty...  Met Collection
#
#                                     Met Collection URL  Wikipedia  \
# 25                                                 NaN  Wikipedia
# 29                                                 NaN  Wikipedia
# 36   https://www.metmuseum.org/art/collection/searc...  Wikipedia
# 39                                                 NaN  Wikipedia
# 121                                                NaN  Wikipedia
# ..                                                 ...        ...
# 881                                                NaN  Wikipedia
# 889                                                NaN        NaN
# 902                                                NaN        NaN
# 903  https://www.metmuseum.org/art/collection/searc...  Wikipedia
# 929  https://www.metmuseum.org/art/collection/searc...  Wikipedia
#
#                                      Wikipedia URL Art Asia America  \
# 25         https://en.wikipedia.org/wiki/Leo_Amino              NaN
# 29       https://en.wikipedia.org/wiki/Toshio_Aoki              NaN
# 36   https://en.wikipedia.org/wiki/Shusaku_Arakawa              NaN
# 39        https://en.wikipedia.org/wiki/Ruth_Asawa              NaN
# 121    https://en.wikipedia.org/wiki/Junko_Chodos     artasiamerica
# ..                                             ...              ...
# 881     https://en.wikipedia.org/wiki/Taro_Yashima              NaN
# 889                                            NaN              NaN
# 902                                            NaN              NaN
# 903  https://en.wikipedia.org/wiki/Fumio_Yoshimura              NaN
# 929    https://en.wikipedia.org/wiki/Chuzo_Tamotzu              NaN
#
#                                        AAA URL
# 25                                         NaN
# 29                                         NaN
# 36                                         NaN
# 39                                         NaN
# 121  http://artasiamerica.org/artist/detail/37
# ..                                         ...
# 881                                        NaN
# 889                                        NaN
# 902                                        NaN
# 903                                        NaN
# 929                                        NaN
#
# [144 rows x 20 columns]

# %% [markdown]
# Looks good? Let's assign this slice to its own variable and use `.info()` to get some information about it.

# %%
jn_pre1942 = moma[jn_pre1942_index]
jn_pre1942.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 144 entries, 25 to 929
# Data columns (total 20 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Match point         144 non-null    object
#  1   ULAN ID             64 non-null     float64
#  2   Wikidata ID         144 non-null    object
#  3   VIAF ID             86 non-null     float64
#  4   LC ID               70 non-null     object
#  5   Name                144 non-null    object
#  6   Label               142 non-null    object
#  7   Birth date          144 non-null    float64
#  8   Death date          110 non-null    float64
#  9   Ancestry/Heritage   144 non-null    object
#  10  Indexes             0 non-null      object
#  11  Description         144 non-null    object
#  12  Watsonline          144 non-null    object
#  13  Watsonline URL      144 non-null    object
#  14  Met Collection      23 non-null     object
#  15  Met Collection URL  23 non-null     object
#  16  Wikipedia           75 non-null     object
#  17  Wikipedia URL       75 non-null     object
#  18  Art Asia America    8 non-null      object
#  19  AAA URL             8 non-null      object
# dtypes: float64(4), object(16)
# memory usage: 23.6+ KB

# %% [markdown]
# #### Quiz
# How many artists of Japanese descent in the dataset were born before 1942? How do you know?

# %%
jn_pre1942.shape
# Out:
# (144, 20)

# %% [markdown]
# ### Sorting
# In order to sort a DataFrame by a specific column, we can use the [**DataFrame.sort_values()**](https://pandas.pydata.org/docs/dev/reference/api/pandas.DataFrame.sort_values.html#pandas.DataFrame.sort_values) function. The sort_values() takes in a *column name* so we can tell Pandas what to sort the rows by.

# %%
moma.sort_values(by="Death date")
# Out:
#     Match point      ULAN ID Wikidata ID      VIAF ID        LC ID  \
# 917   AAPI-0057  500107140.0     Q163298   94645020.0    n83158786
# 319   AAPI-0782          NaN  Q120867937          NaN          NaN
# 388   AAPI-0787          NaN  Q120867918          NaN          NaN
# 29    AAPI-0020  500465254.0   Q17421288          NaN          NaN
# 755   AAPI-0821          NaN   Q81027329          NaN          NaN
# ..          ...          ...         ...          ...          ...
# 924   AAPI-1052          NaN  Q120717727          NaN          NaN
# 925   AAPI-0890  500524609.0   Q21607972  307424125.0  n2014002953
# 926   AAPI-0735          NaN    Q8070726          NaN          NaN
# 927   AAPI-0736          NaN  Q120867919          NaN          NaN
# 928   AAPI-0889          NaN  Q120868879          NaN          NaN
#
#                   Name             Label  Birth date  Death date  \
# 917      Zhang, Daqian      Daqian Zhang      1899.0      1893.0
# 319       Kagi, Tameya       Tameya Kagi      1851.0      1894.0
# 388   Kobayashi, Senko   Senko Kobayashi      1870.0      1911.0
# 29        Aoki, Toshio       Toshio Aoki      1854.0      1912.0
# 755  Takahashi, Katsuo  Katsuo Takahashi      1860.0      1917.0
# ..                 ...               ...         ...         ...
# 924          Zhao, Pop          Pop Zhao      1963.0         NaN
# 925    Zheng, Chongbin    Chongbin Zheng      1961.0         NaN
# 926     Zheng, Lianjie     Lianjie Zheng      1962.0         NaN
# 927   Zheng, Shengtian   Shengtian Zheng      1938.0         NaN
# 928     Zhong, Yueying     Yueying Zhong      1960.0         NaN
#
#     Ancestry/Heritage Indexes  \
# 917           Chinese     NaN
# 319          Japanese     NaN
# 388          Japanese     NaN
# 29           Japanese     NaN
# 755          Japanese     NaN
# ..                ...     ...
# 924           Chinese     NaN
# 925           Chinese     NaN
# 926           Chinese     NaN
# 927           Chinese     NaN
# 928           Chinese     NaN
#
#                                            Description  Watsonline  \
# 917                    painter;ink artist/calligrapher  Watsonline
# 319                                            painter  Watsonline
# 388                                            painter  Watsonline
# 29                     painter;ink artist/calligrapher  Watsonline
# 755                       painter;textile/fiber artist  Watsonline
# ..                                                 ...         ...
# 924                                                NaN  Watsonline
# 925  installation artist;painter;time-based media a...  Watsonline
# 926  installation artist;painter;performance artist...  Watsonline
# 927                    painter;ink artist/calligrapher  Watsonline
# 928                    painter;ink artist/calligrapher  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 917  https://library.metmuseum.org/search/?searchty...             NaN
# 319  https://library.metmuseum.org/search~S1/?searc...             NaN
# 388  https://library.metmuseum.org/search~S1/?searc...             NaN
# 29   https://library.metmuseum.org/search~S1/?searc...             NaN
# 755  https://library.metmuseum.org/search~S1/?searc...             NaN
# ..                                                 ...             ...
# 924  https://library.metmuseum.org/search~S1/?searc...             NaN
# 925  https://library.metmuseum.org/search/?searchty...  Met Collection
# 926  https://library.metmuseum.org/search~S1/?searc...             NaN
# 927  https://library.metmuseum.org/search~S1/?searc...             NaN
# 928  https://library.metmuseum.org/search~S1/?searc...             NaN
#
#                                     Met Collection URL  Wikipedia  \
# 917                                                NaN  Wikipedia
# 319                                                NaN        NaN
# 388                                                NaN        NaN
# 29                                                 NaN  Wikipedia
# 755                                                NaN        NaN
# ..                                                 ...        ...
# 924                                                NaN        NaN
# 925  https://www.metmuseum.org/art/collection/searc...        NaN
# 926                                                NaN  Wikipedia
# 927                                                NaN        NaN
# 928                                                NaN        NaN
#
#                                      Wikipedia URL Art Asia America  \
# 917  https://en.wikipedia.org/wiki/Chang_Dai-chien              NaN
# 319                                            NaN              NaN
# 388                                            NaN              NaN
# 29       https://en.wikipedia.org/wiki/Toshio_Aoki              NaN
# 755                                            NaN              NaN
# ..                                             ...              ...
# 924                                            NaN              NaN
# 925                                            NaN              NaN
# 926    https://en.wikipedia.org/wiki/Zheng_Lianjie    artasiamerica
# 927                                            NaN              NaN
# 928                                            NaN              NaN
#
#                                        AAA URL
# 917                                        NaN
# 319                                        NaN
# 388                                        NaN
# 29                                         NaN
# 755                                        NaN
# ..                                         ...
# 924                                        NaN
# 925                                        NaN
# 926  http://artasiamerica.org/artist/detail/57
# 927                                        NaN
# 928                                        NaN
#
# [930 rows x 20 columns]

# %% [markdown]
# This pattern of applying the output of one function to another using `.` is called **chaining**. It is very common in Pandas, where the same DataFrame or Series will undergo several consecutive transformations.

# %% [markdown]
# #### Quiz
#  How can we use filtering, sorting, and head to find the three youngest artists of Chinese descent in the dataset?

# %%
 chinese_artists = moma[moma["Ancestry/Heritage"] == "Chinese"]

# %% [markdown]
# First get the artists of Chinese descent, then sort them by `birth_date`.

# %% [markdown]
# By default, these are sorted in ascending order, let's switch to descending order using the `ascending` argument.

# %%
chinese_artists.sort_values(by=["Birth date"]).head(3)
# Out:
#     Match point  ULAN ID Wikidata ID  VIAF ID LC ID           Name  \
# 894   AAPI-0843      NaN  Q120717654      NaN   NaN      Yong, Lai
# 773   AAPI-0824      NaN   Q27978700      NaN   NaN     Tape, Mary
# 876   AAPI-0839      NaN  Q109628772      NaN   NaN  Yang, Ling-fu
#
#             Label  Birth date  Death date Ancestry/Heritage Indexes  \
# 894      Lai Yong      1840.0         NaN           Chinese     NaN
# 773     Mary Tape      1857.0      1934.0           Chinese     NaN
# 876  Ling-fu Yang      1888.0      1978.0           Chinese     NaN
#
#               Description  Watsonline  \
# 894  painter;photographer  Watsonline
# 773  painter;photographer  Watsonline
# 876               painter  Watsonline
#
#                                         Watsonline URL Met Collection  \
# 894  https://library.metmuseum.org/search~S1/?searc...            NaN
# 773  https://library.metmuseum.org/search~S1/?searc...            NaN
# 876  https://library.metmuseum.org/search~S1/?searc...            NaN
#
#     Met Collection URL  Wikipedia                               Wikipedia URL  \
# 894                NaN        NaN                                         NaN
# 773                NaN  Wikipedia     https://en.wikipedia.org/wiki/Mary_Tape
# 876                NaN  Wikipedia  https://en.wikipedia.org/wiki/Yang_Ling-fu
#
#     Art Asia America AAA URL
# 894              NaN     NaN
# 773              NaN     NaN
# 876              NaN     NaN

# %%
chinese_artists.sort_values(by=["Birth date"], ascending=False).head(3)
# Out:
#     Match point      ULAN ID Wikidata ID  VIAF ID LC ID                Name  \
# 637   AAPI-1246          NaN  Q120077443      NaN   NaN    Ouyang, Catalina
# 722   AAPI-1040  500778584.0   Q76500450      NaN   NaN        Sin, Wai Kin
# 107   AAPI-0084          NaN  Q120717769      NaN   NaN  Cheng, Luke Luokun
#
#                  Label  Birth date  Death date Ancestry/Heritage Indexes  \
# 637    Catalina Ouyang      1993.0         NaN           Chinese     NaN
# 722                NaN      1991.0         NaN           Chinese     NaN
# 107  Luke Luokun Cheng      1991.0         NaN           Chinese     NaN
#
#                                 Description  Watsonline  \
# 637                                sculptor  Watsonline
# 722    multimedia artist;performance artist  Watsonline
# 107  installation artist;performance artist  Watsonline
#
#                                         Watsonline URL Met Collection  \
# 637  https://library.metmuseum.org/search~S1/?searc...            NaN
# 722  https://library.metmuseum.org/search/?searchty...            NaN
# 107  https://library.metmuseum.org/search~S1/?searc...            NaN
#
#     Met Collection URL  Wikipedia  \
# 637                NaN        NaN
# 722                NaN  Wikipedia
# 107                NaN        NaN
#
#                                    Wikipedia URL Art Asia America AAA URL
# 637                                          NaN              NaN     NaN
# 722  https://en.wikipedia.org/wiki/Victoria_Sin               NaN     NaN
# 107                                          NaN              NaN     NaN

# %% [markdown]
# **Q:** Can you use **.loc[]** and compound boolean indexing to find the `Name` and `Description` of all the millenials in the dataset.
# For our purposes, let's say a millenial is someone born between 1981 and 1996 inclusive.

# %% [markdown]
# First compute boolean indices for each of the two conditions: born >= 1981 AND born <= 1996.

# %%
moma["Birth date"] >= 1981
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# Name: Birth date, Length: 930, dtype: bool

# %%
moma["Birth date"] <= 1996
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 925    True
# 926    True
# 927    True
# 928    True
# 929    True
# Name: Birth date, Length: 930, dtype: bool

# %% [markdown]
# Then, use `&` to find the intersection of the two boolean indexes.
# Assign the result to the variable `millenial_index`.

# %%
millenial_index = (moma["Birth date"] >= 1981) & (moma["Birth date"] <= 1996)

# %% [markdown]
# Then, assign the millenial rows to `millenials`.

# %%
millenials = moma[millenial_index]
millenials
# Out:
#     Match point      ULAN ID Wikidata ID       VIAF ID         LC ID  \
# 9     AAPI-0007          NaN   Q19597819           NaN           NaN
# 19    AAPI-1032  500372656.0   Q61997639  3.612150e+21           NaN
# 24    AAPI-1050          NaN  Q120077483           NaN           NaN
# 38    AAPI-0027          NaN   Q31087622  3.155584e+08           NaN
# 54    AAPI-1161          NaN  Q120717730           NaN           NaN
# ..          ...          ...         ...           ...           ...
# 801   AAPI-0637          NaN   Q50825806  1.367160e+21           NaN
# 811   AAPI-0650          NaN   Q77325044           NaN           NaN
# 818   AAPI-1262          NaN   Q44627574  2.815290e+19  no2018073615
# 830   AAPI-0666          NaN  Q111490819           NaN           NaN
# 848   AAPI-0678  500487448.0   Q70018807  1.154920e+18           NaN
#
#                         Name                   Label  Birth date  Death date  \
# 9              Aguhar, Mark              Mark Aguhar      1987.0      2012.0
# 19             Akashi, Kelly            Kelly Akashi      1983.0         NaN
# 24               Amano, Fumi              Fumi Amano      1985.0         NaN
# 38   Arunanondchai, Korakrit  Korakrit Arunanondchai      1986.0         NaN
# 54              Bhow, Ragini             Ragini Bhow      1991.0         NaN
# ..                       ...                     ...         ...         ...
# 801              Tse, Ka-Man              Ka-Man Tse      1981.0         NaN
# 811           Tuttle, Martha           Martha Tuttle      1989.0         NaN
# 818             Uoo, Stewart             Stewart Uoo      1985.0         NaN
# 830                 Wangshui                Wangshui      1986.0         NaN
# 848            Wong, Matthew            Matthew Wong      1984.0      2019.0
#
#       Ancestry/Heritage Indexes  \
# 9          Filipino/a/x     NaN
# 19             Japanese     NaN
# 24             Japanese     NaN
# 38                 Thai     NaN
# 54               Indian     NaN
# ..                  ...     ...
# 801          Hongkonger     NaN
# 811             Chinese     NaN
# 818              Korean     NaN
# 830             Chinese     NaN
# 848  Hongkonger;Chinese     NaN
#
#                                            Description  Watsonline  \
# 9    multidisciplinary artist;multimedia artist;per...  Watsonline
# 19                                            sculptor  Watsonline
# 24                                            sculptor  Watsonline
# 38           multimedia artist;time-based media artist  Watsonline
# 54                                    painter;sculptor  Watsonline
# ..                                                 ...         ...
# 801               photographer;time-based media artist  Watsonline
# 811  interdisciplinary artist;painter;sculptor;text...  Watsonline
# 818           painter;sculptor;time-based media artist  Watsonline
# 830  installation artist;sculptor;time-based media ...  Watsonline
# 848                                            painter  Watsonline
#
#                                         Watsonline URL  Met Collection  \
# 9    https://library.metmuseum.org/search~S1/?searc...             NaN
# 19   https://library.metmuseum.org/search/?searchty...             NaN
# 24   https://library.metmuseum.org/search~S1/?searc...             NaN
# 38   https://library.metmuseum.org/search~S1/?searc...             NaN
# 54   https://library.metmuseum.org/search~S1/?searc...             NaN
# ..                                                 ...             ...
# 801  https://library.metmuseum.org/search~S1/?searc...             NaN
# 811  https://library.metmuseum.org/search~S1/?searc...             NaN
# 818  https://library.metmuseum.org/search~S1/?searc...             NaN
# 830  https://library.metmuseum.org/search~S1/?searc...             NaN
# 848  https://library.metmuseum.org/search~S1/?searc...  Met Collection
#
#                                     Met Collection URL  Wikipedia  \
# 9                                                  NaN  Wikipedia
# 19                                                 NaN        NaN
# 24                                                 NaN        NaN
# 38                                                 NaN  Wikipedia
# 54                                                 NaN        NaN
# ..                                                 ...        ...
# 801                                                NaN  Wikipedia
# 811                                                NaN        NaN
# 818                                                NaN  Wikipedia
# 830                                                NaN  Wikipedia
# 848  https://www.metmuseum.org/art/collection/searc...  Wikipedia
#
#                                          Wikipedia URL Art Asia America  \
# 9            https://en.wikipedia.org/wiki/Mark_Aguhar              NaN
# 19                                                 NaN              NaN
# 24                                                 NaN              NaN
# 38   https://en.wikipedia.org/wiki/Korakrit_Arunano...              NaN
# 54                                                 NaN              NaN
# ..                                                 ...              ...
# 801           https://en.wikipedia.org/wiki/Ka-Man_Tse              NaN
# 811                                                NaN              NaN
# 818          https://en.wikipedia.org/wiki/Stewart_Uoo              NaN
# 830             https://en.wikipedia.org/wiki/WangShui              NaN
# 848         https://en.wikipedia.org/wiki/Matthew_Wong              NaN
#
#     AAA URL
# 9       NaN
# 19      NaN
# 24      NaN
# 38      NaN
# 54      NaN
# ..      ...
# 801     NaN
# 811     NaN
# 818     NaN
# 830     NaN
# 848     NaN
#
# [61 rows x 20 columns]

# %% [markdown]
# Now that we've identified the millenials in `millenials`, let's use `.loc[]` and a list of column names to select the `Name` and `Description` columns.

# %%
millenials.loc[:, ["Name", "Description"]]
# Out:
#                         Name  \
# 9              Aguhar, Mark
# 19             Akashi, Kelly
# 24               Amano, Fumi
# 38   Arunanondchai, Korakrit
# 54              Bhow, Ragini
# ..                       ...
# 801              Tse, Ka-Man
# 811           Tuttle, Martha
# 818             Uoo, Stewart
# 830                 Wangshui
# 848            Wong, Matthew
#
#                                            Description
# 9    multidisciplinary artist;multimedia artist;per...
# 19                                            sculptor
# 24                                            sculptor
# 38           multimedia artist;time-based media artist
# 54                                    painter;sculptor
# ..                                                 ...
# 801               photographer;time-based media artist
# 811  interdisciplinary artist;painter;sculptor;text...
# 818           painter;sculptor;time-based media artist
# 830  installation artist;sculptor;time-based media ...
# 848                                            painter
#
# [61 rows x 2 columns]

# %% [markdown]
# ### Interlude: Dictionaries
# [**Dictionaries**](https://docs.python.org/3/tutorial/datastructures.html#dictionaries) are sets of **key-value** pairs indicated by {} in the form `{k1: v1, k2: v2..}`.
#
# * Dictionary keys must be unique.
# * Dictionary values do not need to be.
# * If you know your key, dictionaries give you the corresponding value quickly.

# %% [markdown]
# Let's create a toy dictionary with patient names as *keys* and their diagnoses as *values*.

# %%
patients = {}
patients["John"] = "kidney stones"
patients["David"] = "fever"
patients["Steven"] = "fever"
print(patients)
# Out:
# {'John': 'kidney stones', 'David': 'fever', 'Steven': 'fever'}

# %% [markdown]
# There are two ways to get values out of a dictionary by their keys: using the [] syntax or using a method called .get().

# %%
patients["John"]
# Out:
# 'kidney stones'

# %% [markdown]
# The `[]` lookup syntax will fail with a **KeyError** if you try to lookup a key that is not in the dictionary.

# %%
patients["Emily"] # This will error out
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 patients["Emily"]
#
# KeyError: 'Emily'

# %% [markdown]
# To prevent your code from crashing with a **KeyError**, use the **.get()** method instead, which will return `None` if the specified key is not in the dictionary.

# %%
if (patients.get("Emily")) == None: # this will NOT crash
    print("Emily is not in the dictionary")
print(patients.get("David"))
# Out:
# Emily is not in the dictionary
# fever

# %% [markdown]
# Dictionary *keys* must be immutable, but dictionary *values* can be just about anything.
#
# **Hint**: The *mutable* objects you've encountered so far include lists and dictionaries.

# %% [markdown]
# You *can* use lists as values in dictionaries, and in fact, it's convenient to do so.

# %%
hospital = {"name": ["adam", "yao", "sam"], "ages":[15, 25, 30]}
hospital
# Out:
# {'name': ['adam', 'yao', 'sam'], 'ages': [15, 25, 30]}

# %% [markdown]
# ### Wait, What Does This Have to Do with Pandas?

# %% [markdown]
# We can construct toy **Series** from lists by passing in a list of values *and* an index of the same length. (Remember, a **Series** is a one-dimensional array with an alphanumeric index.)

# %%
s = pd.Series(["cat", "dog", "antelope"]) # no index provided, defaults to rangeindex
s
# Out:
# 0         cat
# 1         dog
# 2    antelope
# dtype: object

# %%
z = pd.Series(data=["cat", "dog", "antelope"], index=["c", "d", "a"])
z
# Out:
# c         cat
# d         dog
# a    antelope
# dtype: object

# %% [markdown]
# We can construct **DataFrames** from dictionaries of rows. Let's take the `hospital` dictionary from above. Note that the $nth$ item in the list corresponds to $nth$ row in the resulting DataFrame .

# %%
hospital_frame = pd.DataFrame(data=hospital, index=[101, 102, 103])
hospital_frame
# Out:
#      name  ages
# 101  adam    15
# 102   yao    25
# 103   sam    30

# %% [markdown]
# In this example, patients are indexed by a fake patient_id number. We can use **.loc[]** to retrieve rows by that index.

# %%
hospital_frame.loc[101]
# Out:
# name    adam
# ages      15
# Name: 101, dtype: object

# %% [markdown]
# There are many functions in Pandas that take in dictionaries or lists as **arguments**, so make sure you're comfortable with these data structures.

# %% [markdown]
# ## Missing Values
# How to best handle missing values depends on your source data and the task you want to complete with your data. Though Pandas supports different missing value indicators, the most frequent, and the one you will observe when reading in empty cells from a file, is `numpy.nan`.

# %%
import numpy as np
pet_counts = pd.DataFrame({"name":["Jose", "David", "Rose", np.nan], "pets": [1, np.nan, 3, 5]})
pet_counts
# Out:
#     name  pets
# 0   Jose   1.0
# 1  David   NaN
# 2   Rose   3.0
# 3    NaN   5.0

# %% [markdown]
# NaNs do not count towards aggegated metrics like **count()**, **sum()**, or **mean()**.

# %%
pet_counts.count()
# Out:
# name    3
# pets    3
# dtype: int64

# %%
pet_counts["pets"].mean() # The missing value will not count towards this average
# Out:
# 3.0

# %% [markdown]
# ### Detecting Missing Values

# %% [markdown]
# np.nan is **not** `None` or `0`. You will need use a set of [specialized functions](https://pandas.pydata.org/docs/user_guide/missing_data.html#calculations-with-missing-data) from Pandas to test for or replace it.

# %%
pet_counts
# Out:
#     name  pets
# 0   Jose   1.0
# 1  David   NaN
# 2   Rose   3.0
# 3    NaN   5.0

# %%
pet_counts.loc[1 , "pets"] == None
# Out:
# False

# %% [markdown]
# **pd.isna()** can be used to check a single value.

# %%
pd.isna(pet_counts.loc[1, "pets"])
# Out:
# True

# %% [markdown]
# To detect NaNs in a DataFrame or Series, we can use the [**isna()**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html#pandas.DataFrame.isna) method that returns a boolean array *of the same size as the input DataFrame*.

# %%
pet_counts.isna()
# Out:
#     name   pets
# 0  False  False
# 1  False   True
# 2  False  False
# 3   True  False

# %%
pet_counts.isna().sum() # Total # of Nans per column
# Out:
# name    1
# pets    1
# dtype: int64

# %% [markdown]
# Pandas also has a method for computing the opposite: which entries in a DataFrame are not null. This is [**notna()**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.notna.html#pandas.DataFrame.notna).

# %%
pet_counts.notna()
# Out:
#     name   pets
# 0   True   True
# 1   True  False
# 2   True   True
# 3  False   True

# %% [markdown]
# We can then aggregate the returned frame to count the number of non-null values per column.

# %%
pet_counts.notna().sum()
# Out:
# name    3
# pets    3
# dtype: int64

# %% [markdown]
# The Pandas [**fillna()**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.fillna.html) function allows us to replace NaNs with a default value.

# %%
pet_counts.fillna(0)
# Out:
#     name  pets
# 0   Jose   1.0
# 1  David   0.0
# 2   Rose   3.0
# 3      0   5.0

# %% [markdown]
# Keep in mind that DataFrame methods return an altered copy of the original DataFrame. They does not change the original.

# %%
pet_counts
# Out:
#     name  pets
# 0   Jose   1.0
# 1  David   NaN
# 2   Rose   3.0
# 3    NaN   5.0

# %% [markdown]
# While 0 might be acceptable for an unknown number of pets (let's say participants were asked to fill in a blank), 0 is *not* an appropriate indicator for an unknown participant name.
#
# **Q:** How can we construct a dictionary that replaces NaNs in the "pets" column with 0 and an unknown name with "UNKNOWN"?

# %%
replacements = {"pets":0, "name":"UNKNOWN"} # In column name: replacement value form

# %%
pet_counts.fillna(value=replacements) # Use the value keyword to specify the dictionary
# Out:
#       name  pets
# 0     Jose   1.0
# 1    David   0.0
# 2     Rose   3.0
# 3  UNKNOWN   5.0

# %% [markdown]
# But what if you simply want to remove problematic columns or rows from your dataset?
#
# The [**DataFrame.dropna()**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html#pandas.DataFrame.dropna) method by default removes all rows with one or more missing values.

# %%
pet_counts.dropna() # By default this drops all rows with one or missing values
# Out:
#    name  pets
# 0  Jose   1.0
# 2  Rose   3.0

# %% [markdown]
# If we use the `subset=` argument, we can pass in a list of columns that determine what rows are dropped. For example, if we pass in a list containing `name` but not `"pets"`, then rows with nulls in the `name` column will be dropped, but nulls in the `pets` column will be ignored.

# %%
pet_counts.dropna(subset=["name"]) # Takes in a list of column names
# Out:
#     name  pets
# 0   Jose   1.0
# 1  David   NaN
# 2   Rose   3.0

# %% [markdown]
# To finalize our changes to the `pet_counts` frame, we must assign the return value of pet_counts to pet_counts as follows. Be very cautious when dropping rows and columns, and assign to a new variable if you're not sure.

# %%
pet_counts = pet_counts.dropna() # Takes in a list of column names
pet_counts
# Out:
#    name  pets
# 0  Jose   1.0
# 2  Rose   3.0

# %% [markdown]
# If you like to learn more about options for handling missing values in Pandas, they have
# an [official guide](https://pandas.pydata.org/docs/user_guide/missing_data.html) that discusses the topic in depth.

# %% [markdown]
# ### Putting it Together: Filtering Rows, Selecting Columns
#
# Let's say you want to amend some of this data by providing missing descriptions for artists without them. The easiest place to start would be to identify artists with *Wikipedia* pages, as those will likely have enough information to supply the missing description.

# %% [markdown]
# Let's generate a boolean index and **.notna()** and **.isna()** to find artists *with* Wikipedia pages but *without* descriptions?

# %%
(moma["Description"].isna()) & (moma["Wikipedia URL"].notna())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 925    False
# 926    False
# 927    False
# 928    False
# 929    False
# Length: 930, dtype: bool

# %% [markdown]
# Now, let's apply this selection and restrict it to the `Name`, `Description`, and `Wikipedia URL` columns.

# %%
moma[(moma["Description"].isna()) & (moma["Wikipedia URL"].notna())].loc[:, ["Name", "Description", "Wikipedia URL"]]
# Out:
#                 Name Description                                 Wikipedia URL
# 60       Bonk, Keiko         NaN      https://en.wikipedia.org/wiki/Keiko_Bonk
# 112      Chiang, Fay         NaN      https://en.wikipedia.org/wiki/Fay_Chiang
# 113   Chiang, Janice         NaN   https://en.wikipedia.org/wiki/Janice_Chiang
# 115      Chin, Frank         NaN      https://en.wikipedia.org/wiki/Frank_Chin
# 630  Osorio, Jamaica         NaN  https://en.wikipedia.org/wiki/Jamaica_Osorio

# %% [markdown]
# ## Renaming Columns and Rows
# Naming variables with spaces (like `"Wikipedia URL"`) is not best practice. Let's go about fixing that.
#
# We can use [**DataFrame.rename()**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html) to pass in key-value pairs that map old names to new ones. We can use rename on either row names or column names.

# %% [markdown]
# The most straightfoward to use **.rename()** is pass in a dictionary of `{'old_name':'new_name','old_name1':'new_name1'...}` mappings as an keyword argument to either `index=` or `columns=` respectively.

# %% [markdown]
# For example, we could rename the `"Wikipedia URL"` and `"Birth date"` columns like this.

# %%
new_names = {"Wikipedia URL":"WikiURL", "Birth date":"Birth"} # Create a dictionary
moma.rename(columns=new_names).head(5)
# Out:
#   Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 0   AAPI-0001  500487777.0     Q466654   79468708.0     n86857749
# 1   AAPI-0970          NaN   Q47157454  102816611.0  no2007063757
# 2   AAPI-0002  500116914.0    Q7426381   96547973.0    no99018101
# 3   AAPI-1031          NaN   Q23881684  307448466.0  no2013110010
# 4   AAPI-0003          NaN   Q19867429          NaN           NaN
#
#                    Name                Label  Birth__date  Death date  \
# 0          Abad, Pacita          Pacita Abad       1946.0      2004.0
# 1          Abbas, Hamra          Hamra Abbas       1976.0         NaN
# 2           Abe, Satoru           Satoru Abe       1926.0         NaN
# 3  Abichandani, Jaishri  Jaishri Abichandani       1969.0         NaN
# 4    Acebo Davis, Terry    Terry Acebo Davis       1953.0         NaN
#
#                Ancestry/Heritage Indexes  \
# 0                   Filipino/a/x     NaN
# 1                      Pakistani     NaN
# 2  Japanese;Hawaiian (Kamaʻāina)     NaN
# 3                         Indian     NaN
# 4                   Filipino/a/x     NaN
#
#                                          Description  Watsonline  \
# 0                                            painter  Watsonline
# 1               sculptor;painter;installation artist  Watsonline
# 2                                   painter;sculptor  Watsonline
# 3                           interdisciplinary artist  Watsonline
# 4  installation artist;mixed-media artist;printmaker  Watsonline
#
#                                       Watsonline URL Met Collection  \
# 0  https://library.metmuseum.org/search~S1/?searc...            NaN
# 1  https://library.metmuseum.org/search~S1/?searc...            NaN
# 2  https://library.metmuseum.org/search~S1/?searc...            NaN
# 3  https://library.metmuseum.org/search/?searchty...            NaN
# 4  https://library.metmuseum.org/search~S1/?searc...            NaN
#
#   Met Collection URL  Wikipedia  \
# 0                NaN  Wikipedia
# 1                NaN        NaN
# 2                NaN  Wikipedia
# 3                NaN        NaN
# 4                NaN  Wikipedia
#
#                                       Wikipedia_URL Art Asia America AAA URL
# 0         https://en.wikipedia.org/wiki/Pacita_Abad              NaN     NaN
# 1                                               NaN              NaN     NaN
# 2          https://en.wikipedia.org/wiki/Satoru_Abe              NaN     NaN
# 3                                               NaN              NaN     NaN
# 4  https://en.wikipedia.org/wiki/Terry_Acebo_Davis               NaN     NaN

# %% [markdown]
# **.rename()** will ignore columns or indices that do not exist in your DataFrame. If the old_name of the `old:new` pair doesn't exist, that change isn't applied and that renaming operation will be ignored.

# %%
moma.rename(index=new_names).head(5) # Rename rows when we mean to rename columns
# Out:
#   Match point      ULAN ID Wikidata ID      VIAF ID         LC ID  \
# 0   AAPI-0001  500487777.0     Q466654   79468708.0     n86857749
# 1   AAPI-0970          NaN   Q47157454  102816611.0  no2007063757
# 2   AAPI-0002  500116914.0    Q7426381   96547973.0    no99018101
# 3   AAPI-1031          NaN   Q23881684  307448466.0  no2013110010
# 4   AAPI-0003          NaN   Q19867429          NaN           NaN
#
#                    Name                Label  Birth date  Death date  \
# 0          Abad, Pacita          Pacita Abad      1946.0      2004.0
# 1          Abbas, Hamra          Hamra Abbas      1976.0         NaN
# 2           Abe, Satoru           Satoru Abe      1926.0         NaN
# 3  Abichandani, Jaishri  Jaishri Abichandani      1969.0         NaN
# 4    Acebo Davis, Terry    Terry Acebo Davis      1953.0         NaN
#
#                Ancestry/Heritage Indexes  \
# 0                   Filipino/a/x     NaN
# 1                      Pakistani     NaN
# 2  Japanese;Hawaiian (Kamaʻāina)     NaN
# 3                         Indian     NaN
# 4                   Filipino/a/x     NaN
#
#                                          Description  Watsonline  \
# 0                                            painter  Watsonline
# 1               sculptor;painter;installation artist  Watsonline
# 2                                   painter;sculptor  Watsonline
# 3                           interdisciplinary artist  Watsonline
# 4  installation artist;mixed-media artist;printmaker  Watsonline
#
#                                       Watsonline URL Met Collection  \
# 0  https://library.metmuseum.org/search~S1/?searc...            NaN
# 1  https://library.metmuseum.org/search~S1/?searc...            NaN
# 2  https://library.metmuseum.org/search~S1/?searc...            NaN
# 3  https://library.metmuseum.org/search/?searchty...            NaN
# 4  https://library.metmuseum.org/search~S1/?searc...            NaN
#
#   Met Collection URL  Wikipedia  \
# 0                NaN  Wikipedia
# 1                NaN        NaN
# 2                NaN  Wikipedia
# 3                NaN        NaN
# 4                NaN  Wikipedia
#
#                                       Wikipedia URL Art Asia America AAA URL
# 0         https://en.wikipedia.org/wiki/Pacita_Abad              NaN     NaN
# 1                                               NaN              NaN     NaN
# 2          https://en.wikipedia.org/wiki/Satoru_Abe              NaN     NaN
# 3                                               NaN              NaN     NaN
# 4  https://en.wikipedia.org/wiki/Terry_Acebo_Davis               NaN     NaN

# %% [markdown]
# Keep in mind that this mistake continues silently (without throwing an error) when debugging code.

# %% [markdown]
# ### Batch Renaming With String Functions
# There are several column names in this DataFrame with spaces in them. Do we really have to type out them all?
#
# Pandas has special string-processing functions for Series and DataFrames inspired by Python's built-in [string operations](https://docs.python.org/3/library/stdtypes.html#string-methods) methods.

# %% [markdown]
# Let's review a few string methods: `str.lower()`, `str.isnumeric()`, `str.replace()`.

# %% [markdown]
# `str.lower()` returns a lowercase version of the string.

# %%
shouting = "ALL CAPS"
shouting.lower()
# Out:
# 'all caps'

# %% [markdown]
# `str.isnumeric()` tests whether or not a string is a number. Any alphabetic characters will cause this to return `False`.

# %%
shouting.isnumeric()
# Out:
# False

# %%
lucky = "12"
lucky.isnumeric()
# Out:
# True

# %% [markdown]
# `str.replace(old, new)` returns a copy of a string with all occurrences of substring `old` replaced by `new`.

# %% [markdown]
# A *substring* is 1 or more consecutive characters inside an existing string.
# `"BAG"` is a substring of `"BAGEL"` but `"NEW YORK"` is not.

# %%
less_shouting = str.replace(shouting, "ALL", "some")
less_shouting
# Out:
# 'some CAPS'

# %% [markdown]
# The `str.replace()` function is especially convenient for removing unwanted characters.

# %%
has_spaces = "This has spaces"
has_spaces.replace(" ", "_") # Replaces spaces with _
# Out:
# 'This_has_spaces'

# %% [markdown]
# Wouldn't it be convenient if we could apply these to all of our columns at once?
#
# That's where [`Series.str.replace()`](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.replace.html#pandas.Series.str.replace) comes in.

# %% [markdown]
# We can access any DataFrame's column names using the `.columns` attribute.

# %%
moma.columns
# Out:
# Index(['Match point', 'ULAN ID', 'Wikidata ID', 'VIAF ID', 'LC ID', 'Name',
#        'Label', 'Birth date', 'Death date', 'Ancestry/Heritage', 'Indexes',
#        'Description', 'Watsonline', 'Watsonline URL', 'Met Collection',
#        'Met Collection URL', 'Wikipedia', 'Wikipedia URL', 'Art Asia America',
#        'AAA URL'],
#       dtype='object')

# %% [markdown]
# Let's use the Pandas version of the `str.replace()` method we already know to replace spaces with the empty string.

# %%
moma.columns.str.replace(" ", "")
# Out:
# Index(['Matchpoint', 'ULANID', 'WikidataID', 'VIAFID', 'LCID', 'Name', 'Label',
#        'Birthdate', 'Deathdate', 'Ancestry/Heritage', 'Indexes', 'Description',
#        'Watsonline', 'WatsonlineURL', 'MetCollection', 'MetCollectionURL',
#        'Wikipedia', 'WikipediaURL', 'ArtAsiaAmerica', 'AAAURL'],
#       dtype='object')

# %% [markdown]
# This returns a **copy** of the column names, so we'll have to assign it back to the DataFrame.

# %%
moma.columns = moma.columns.str.replace(" ", "")
moma.head(5)
# Out:
#   Matchpoint       ULANID WikidataID       VIAFID          LCID  \
# 0  AAPI-0001  500487777.0    Q466654   79468708.0     n86857749
# 1  AAPI-0970          NaN  Q47157454  102816611.0  no2007063757
# 2  AAPI-0002  500116914.0   Q7426381   96547973.0    no99018101
# 3  AAPI-1031          NaN  Q23881684  307448466.0  no2013110010
# 4  AAPI-0003          NaN  Q19867429          NaN           NaN
#
#                    Name                Label  Birthdate  Deathdate  \
# 0          Abad, Pacita          Pacita Abad     1946.0     2004.0
# 1          Abbas, Hamra          Hamra Abbas     1976.0        NaN
# 2           Abe, Satoru           Satoru Abe     1926.0        NaN
# 3  Abichandani, Jaishri  Jaishri Abichandani     1969.0        NaN
# 4    Acebo Davis, Terry    Terry Acebo Davis     1953.0        NaN
#
#                Ancestry/Heritage Indexes  \
# 0                   Filipino/a/x     NaN
# 1                      Pakistani     NaN
# 2  Japanese;Hawaiian (Kamaʻāina)     NaN
# 3                         Indian     NaN
# 4                   Filipino/a/x     NaN
#
#                                          Description  Watsonline  \
# 0                                            painter  Watsonline
# 1               sculptor;painter;installation artist  Watsonline
# 2                                   painter;sculptor  Watsonline
# 3                           interdisciplinary artist  Watsonline
# 4  installation artist;mixed-media artist;printmaker  Watsonline
#
#                                        WatsonlineURL MetCollection  \
# 0  https://library.metmuseum.org/search~S1/?searc...           NaN
# 1  https://library.metmuseum.org/search~S1/?searc...           NaN
# 2  https://library.metmuseum.org/search~S1/?searc...           NaN
# 3  https://library.metmuseum.org/search/?searchty...           NaN
# 4  https://library.metmuseum.org/search~S1/?searc...           NaN
#
#   MetCollectionURL  Wikipedia  \
# 0              NaN  Wikipedia
# 1              NaN        NaN
# 2              NaN  Wikipedia
# 3              NaN        NaN
# 4              NaN  Wikipedia
#
#                                        WikipediaURL ArtAsiaAmerica AAAURL
# 0         https://en.wikipedia.org/wiki/Pacita_Abad            NaN    NaN
# 1                                               NaN            NaN    NaN
# 2          https://en.wikipedia.org/wiki/Satoru_Abe            NaN    NaN
# 3                                               NaN            NaN    NaN
# 4  https://en.wikipedia.org/wiki/Terry_Acebo_Davis             NaN    NaN

# %% [markdown]
# As a sneak peak of passing functions as arguments, I want to mention you can pass a function like `str.lower()` to rename.

# %% [markdown]
# ## Writing Out DataFrames
# To output a `DataFrame` to disk, we can use one of several fuctions including : `.to_csv()`, `to_excel()`, and `to_sql()`. Let's practice with [`.to_csv()`](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html).

# %% [markdown]
# Let's practice by writing out the cleaned version of the `moma` DataFrame.

# %% [markdown]
# Create a new folder named `output` in your project folder using the File Browser tab.

# %%
moma.to_csv("output/moma_cleaned.csv", index=False)

# %% [markdown]
# This cell will not return any output. Instead, check the contents of the `output` folder and press the refresh symbol if necessary.
